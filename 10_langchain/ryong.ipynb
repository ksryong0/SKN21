# %%
# huggingface 로그인 - 모델 받기 위해.
import os
from dotenv import load_dotenv
from huggingface_hub import login
from transformers import pipeline

hf_key = os.getenv("HUGGINGFACE_API_KEY")
login(hf_key)


model = 'ComfyUI/models/unet'

pipe = pipeline("Image-to-Video", model=model)
# Out:
# ---------------------------------------------------------------------------
# HFValidationError                         Traceback (most recent call last)
# File c:\Users\82109\Documents\class\SKN21\SKN21\10_langchain\.venv\Lib\site-packages\transformers\utils\hub.py:479, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     477 if len(full_filenames) == 1:
#     478     # This is slightly better for only 1 file
# --> 479     hf_hub_download(
#     480         path_or_repo_id,
#     481         filenames[0],
#     482         subfolder=None if len(subfolder) == 0 else subfolder,
#     483         repo_type=repo_type,
#     484         revision=revision,
#     485         cache_dir=cache_dir,
# ...

# %%
# !uv pip install -q -U diffusers transformers accelerate torch torchvision

# %%
# !uv pip install -q diffusers transformers accelerate torch torchvision

# %%
# !uv pip uninstall torch torchvision
# Out:
# Uninstalled 2 packages in 13.62s
#  - torch==2.9.1
#  - torchvision==0.24.1

# %%
# !uv pip install torch==2.8 torchvision
# Out:
# Resolved 13 packages in 118ms
# Installed 2 packages in 12.53s
#  + torch==2.8.0
#  + torchvision==0.23.0

# %%
import torch
from diffusers import StableVideoDiffusionPipeline
from diffusers.utils import load_image, export_to_video
from PIL import Image
# huggingface 로그인 - 모델 받기 위해.
import os
from dotenv import load_dotenv
from huggingface_hub import login
from transformers import pipeline

hf_key = os.getenv("HUGGINGFACE_API_KEY")
login(hf_key)

# 1. 파이프라인 로드 (SVD XT 모델 사용 - 더 긴 영상 생성 가능)
pipe = StableVideoDiffusionPipeline.from_pretrained(
    "stabilityai/stable-video-diffusion-img2vid-xt", 
    torch_dtype=torch.float16, 
    variant="fp16"
)
pipe.to("cpu")

# 2. 이미지 불러오기 및 전처리
image = load_image("red.jpg") # 변환할 이미지 경로
image = image.resize((1024, 576)) # SVD XT 권장 해상도

# 3. 비디오 생성
generator = torch.manual_seed(42)
frames = pipe(
    image, 
    decode_chunk_size=8, 
    generator=generator
).frames[0]

# 4. 결과 비디오 저장
export_to_video(frames, "generated_video.mp4", fps=7)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 2
#       1 import torch
# ----> 2 from diffusers import StableVideoDiffusionPipeline
#       3 from diffusers.utils import load_image, export_to_video
#       4 from PIL import Image
#
# File c:\Users\82109\Documents\class\SKN21\SKN21\10_langchain\.venv\Lib\site-packages\diffusers\__init__.py:5
#       1 __version__ = "0.36.0"
#       3 from typing import TYPE_CHECKING
# ----> 5 from .utils import (
#       6     DIFFUSERS_SLOW_IMPORT,
#       7     OptionalDependencyNotAvailable,
#       8     _LazyModule,
#       9     is_accelerate_available,
#      10     is_bitsandbytes_available,
#      11     is_flax_available,
#      12     is_gguf_available,
#      13     is_k_diffusion_available,
#      14     is_librosa_available,
#      15     is_note_seq_available,
#      16     is_nvidia_modelopt_available,
# ...

# %%
# !uv pip install python-dotenv
# Out:
# Resolved 1 package in 68ms
# Installed 1 package in 86ms
#  + python-dotenv==1.2.1

# %%
# !uv pip install langchain-huggingface transformers
# Out:
# Resolved 36 packages in 150ms
# Installed 34 packages in 2.56s
#  + annotated-types==0.7.0
#  + anyio==4.12.1
#  + certifi==2026.1.4
#  + charset-normalizer==3.4.4
#  + filelock==3.20.3
#  + fsspec==2026.1.0
#  + h11==0.16.0
#  + httpcore==1.0.9
#  + httpx==0.28.1
#  + huggingface-hub==0.36.0
#  + idna==3.11
#  + jsonpatch==1.33
#  + jsonpointer==3.0.0
#  + langchain-core==1.2.7
#  + langchain-huggingface==1.2.0
#  + langsmith==0.6.4
#  + numpy==2.4.1
#  + orjson==3.11.5
#  + pydantic==2.12.5
#  + pydantic-core==2.41.5
#  + pyyaml==6.0.3
#  + regex==2026.1.15
#  + requests==2.32.5
#  + requests-toolbelt==1.0.0
#  + safetensors==0.7.0
#  + tenacity==9.1.2
#  + tokenizers==0.22.2
#  + tqdm==4.67.1
#  + transformers==4.57.6
#  + typing-extensions==4.15.0
#  + typing-inspection==0.4.2
#  + urllib3==2.6.3
#  + uuid-utils==0.13.0
#  + zstandard==0.25.0
