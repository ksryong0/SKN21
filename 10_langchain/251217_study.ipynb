# %% [markdown]
# LECL(LangChain Expression Language):걍 | 로 묶어준거.

# %% [markdown]
# Runnable 객체:랭체인을 더 쓰기 쉽게 연결해주는 객체. 랭체인에서 주로 사용하는 함수들을 사용할 수 있게 해준다.

# %% [markdown]
# AI 에이전트: 목표를 이해하고, 문제 해결을 위해 여러 단계를 자율적으로 거쳐 연속적인 작업을 수행 (목표 설정 → 계획 → 실행 → 피드백 → 개선).

# %% [markdown]
# 주요 특징
# - 자율성 (Autonomy): 사람의 지시 없이 스스로 판단하고 행동합니다.
# - 환경 인지 (Perception): 주변 상황이나 데이터를 인식하고 이해합니다.
# - 계획 및 실행 (Planning & Action): 목표 달성을 위해 복잡한 작업을 작은 단위로 나누고, 외부 도구(API, 웹 등)를 활용해 실행합니다.
# - 학습 및 개선 (Learning & Improvement): 경험을 통해 스스로 학습하고, 성능을 개선합니다.
# - 목표 기반 (Goal-Oriented): 특정 목표(예: 출장 준비, 고객 응대)를 설정하면 이를 달성하기 위해 연속적인 작업을 수행합니다

# %% [markdown]
# ReAct방식(Reasoning(추론) and Acting)
# - Thought->Action->Observation

# %% [markdown]
# Router
# - 어떤 툴을 사용할지 선택

# %% [markdown]
# Agent-Tool Calling
# ![image.png](attachment:image.png)
