# %% [markdown]
# Agentic Systems : Workflow+Agents
# Agent:LLM이 자신의 프로세스와 툴 사용을 동적으로 지시하고 컨트롤하는 시스템
# 라우터:LLM이 다음에 어떤 단계를 취할지 결정. 여러 툴 중에 어떤 툴을 "선택"할지 나타내는 구조.
# LLM에게 얼마나 많은 행동과 역할을 부여할지에 따라 다양한 아키텍쳐로 나타남.
# ![image.png](attachment:image.png)

# %% [markdown]
# ReAct(Reasoning(추론) and acting)
#
# 과정
# Thought->Action->Observation
# <----------------------------> 다시 반복. 생각->행동->관찰 사이클로 반복.

# %% [markdown]
# Agent:Tool Calling
#
# 사고(곱셈 툴이 필요할까?)->행동(곱셈 툴을 실행하자. Tool Calling)->          Tool               -> 툴 결과 반환->사고
#                                             질문에서 argument, 툴 이름을 가져옴

# %% [markdown]
# 구성요소
# 감각-두뇌-행동
#
# 환경을 인식(감각)하고, 이를 바탕으로 생각하고 판단(두뇌)하여 자율적으로 행동.

# %% [markdown]
# 시스템 형태
# 단일 에이전트
# 멀티 에이전트
