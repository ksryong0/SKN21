# %% [markdown]
# # Chain
#
# **Chain**(체인)은 여러 컴포넌트(요소)를 정해진 순서대로 연결하여 **복잡한 AI 작업을 단계별로 자동화**할 수 있도록 돕는 구조이다.
#
# - 각 컴포넌트는 **이전 처리결과를 입력으로 받아 처리한 후 다음 단계로 결과를 전달**한다.
# - 복잡한 작업을 여러 개의 단순한 단계로 나누고, 각 단계를 순차적으로 실행함으로써 전체 작업을 체계적으로 구성할 수 있다.
#
# ## 기본 개념
#
# - 체인은 하나의 LLM 호출에 그치지 않고 **여러 LLM 호출이나 도구 실행등을 순차적으로 연결**하여 실행 할 수 있다.
# - 예를 들어, 사용자의 질문 → 검색 → 요약 → 응답 생성 같은 일련의 작업을 체인으로 구성할 수 있다.
# - 이러한 체인구조를 사용하면 **작업흐름이 명확**해지고 **코드의 재사용성**이 높아지며 **유지 보수 및 확장성이** 향상된다.
#
# ## LangChain에서의 Chain 구성 방식
#
# LangChain은 다음 두 가지 방식을 통해 체인을 구성할 수 있다.
#
# ### 1. Off-the-shelf Chains 방식 (클래식 방식)
#
# - LangChain에서 제공하는 **미리 정의된 Chain 클래스**(예: `LLMChain`, `SequentialChain`, `SimpleSequentialChain`)를 활용하는 방식이다.
# - 각 클래스는 다양한 chain 알고리즘들을 미리 구현한 것으로 상황에 맞는 것을 선택하여 필요한 구성요소를 전달해 생생한다.
# - 이 방식은 LangChain의 **초기 방식**이며, 새로운 기능 확장이나 유연한 구성에 한계가 있기 때문에 현재 **더 이상 사용되지 않음(deprecated)** 상태이다.
#   - 현재 LangChain에서는 권장하지 않는 방식이다.
#
# ### 2. LCEL (LangChain Expression Language) 방식
#
# - LCEL은 체인을 표현식(Expression) 기반의 선언적 파이프라인 방식으로 구성할 수 있도록 설계된 최신 체인 구성 방법이다.
# - 각 컴포넌트들을 `|` 연산자로 연결하여, 흐름이 자연스럽게 이어지는 형태의 체인을 구성한다.
# - LCEL 방식은 간결하고 선언적인 문법을 제공하여 **직관적이고 융통성과 확장성 있는 체인 구성**이 가능하다.
# - LCEL은
#   - 선형적 흐름 구조를 가진다.
#   - 문법이 간결하고 선언적이다.
#   - 체인의 구조가 코드만 봐도 쉽게 파악된다.
#   - 유연하고 확장성이 매우 뛰어나다.
# - `Runnable` 기반 구조
#   - LCEL방식을 구성하는 모든 컴포넌트들은 `Runnable` 이라는 공통 인터페이스를 기반으로 동작한다.
#   - 체인을 구성하는 각 컴포넌트들은 `Runnable` 을 상속하여 구현하여 이를 통해 일관된 실행 인터페이스를 제공한다.
#   - **공통 메소드**:
#     - `invoke()`: 단일 입력에 대한 처리
#     - `batch()`: 다수 입력을 묶어서 한번에 처리
#     - `stream()`: 스트리밍 방식의 요청
#     - `ainvoke()`, `abatch()`, `astream()`: 비동기적 처리 메소드

# %%
# 기존 off the shelf
from dotenv import load_dotenv
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser

load_dotenv()
prompt=ChatPromptTemplate.from_template(
    template="{item}에 어울리는 브랜드 이름 {count}개를 만들어 주세요."
)
model = ChatOpenAI(model="gpt-5-mini")
parser = StrOutputParser()
# input_variable->(프롬프트)->쿼리->(모델)->답변->(파서)->최종 답변

# %%
# 기존 off the shelf
from langchain_classic import LLMChain
# Chain을 구성하는 요소들을 넣어서 생성.
chain = LLMChain( # prompt->model->parser 기본체인을 구성.
    prompt=prompt,
    llm=model,
    output_parser=parser
)
# 첫번째:Prompt -> Prompt에 전달할 값
res = chain.invoke({"item":"가방", "count":3}) 
print(res['text'])
# Out:
# 다음 세 가지 제안드립니다. 각 이름에 간단한 콘셉트와 태그라인도 붙였습니다.
#
# 1) 벨루나 (Belluna)
# - 콘셉트: 모던하고 고급스러운 가죽·미니멀 라인 브랜드
# - 태그라인: 심플의 품격
#
# 2) 시티노마 (Citynoma)
# - 콘셉트: 도시 생활에 맞춘 실용적이고 다용도인 데일리 백
# - 태그라인: 도시를 누비는 동반자
#
# 3) 그린리프 (GreenLeaf / 그린리프)
# - 콘셉트: 재생 소재·친환경 제작을 강조한 에코 브랜드
# - 태그라인: 지구를 담는 가방
#
# 원하시면 타겟 연령대(예: 20대 초중반/직장인 등)나 브랜드 톤(럭셔리/캐주얼/빈티지 등)에 맞춰 이름을 더 제안드릴게요.

# %%
# LCEL
chain2 = prompt | model | parser # '|' 연산자 오버라이딩을 해둠.
print(type(chain2))
res2 = chain2.invoke({"item":"AI Agent 공부해야 할 것", "count":3})
print(res2)
# Out:
# <class 'langchain_core.runnables.base.RunnableSequence'>
# 아래처럼 3가지 제안드립니다. 각 이름은 발음·브랜딩·목적성을 고려해 짧게 설명을 붙였습니다.
#
# 1) 공부메이트 (GongbuMate)
#    - 친근하고 직관적인 이름으로, 학생용 AI 학습 도우미 이미지에 잘 어울립니다.
#
# 2) 에이듀 (AiDu / 에이듀)
#    - AI + Education 결합형 네이밍. 짧고 현대적이며 브랜드화하기 쉽습니다.
#
# 3) 루미AI (LumiAI / 루미에이아이)
#    - '빛(루미)'으로 깨달음·통찰을 상징하는 느낌의 프리미엄·개인화 학습 서비스에 적합합니다.
#
# 원하는 분위기(캐주얼/전문적/국문중심/영문중심)가 있으면 그에 맞춰 더 만들어 드릴게요.

# %% [markdown]
# # Runnable 타입 주요 클래스
#
# ## [Runnable](https://reference.langchain.com/python/langchain_core/runnables/#langchain_core.runnables.base.Runnable)
# - LangChain의 Runnable은 실행 가능한 작업 단위를 캡슐화한 개념으로, 데이터 흐름의 각 단계를 정의하고 **체인(chain) 에 포함 되어**  복잡한 작업의 각 단계를 수행 한다.
# - Chain을 구성하는 class들은 Runnable의 상속 받아 구현한다.
# - **Prompt Template클래스**, **Chat 모델, LLM 모델 클래스**, **Output Parser 클래스** 등 다양한 컴포넌트가 Runnable을 상속받아 구현된다.
#
# ### 주요 특징
# - 작업 단위의 캡슐화:
#     - Runnable은 특정 작업(예: 프롬프트 생성, LLM 호출, 출력 파싱 등)을 수행하는 독립적인 컴포넌트이다.
#     - 각 컴포넌트는 독립적으로 테스트 및 재사용이 가능하며, 조합하여 복잡한 체인을 구성할 수 있다.
# - 체인 연결 및 작업 흐름 관리:
#     - Runnable은 체인(chain, 일련의 연결된 작업 흐름)을 구성하는 기본 단위로 사용된다.
#     - LangChain Expression Language(LCEL)를 사용하면 | 연산자를 통해 여러 Runnable을 쉽게 연결할 수 있다.
#     - 입력과 출력의 형식을 일관되게 유지하여 각 단계가 자연스럽게 연결된다.
# - 모듈화 및 디버깅 용이성:
#     - 각 단계가 명확히 분리되어 문제 발생 시 어느 단계에서 오류가 발생했는지 쉽게 확인할 수 있다.
#     - 복잡한 작업을 작은 단위로 나누어 체계적으로 관리할 수 있다.
#
# ### Runnable의 표준 메소드
# - 모든 Runnable이 구현하는 공통 메소드
#     - **`invoke(input, config:RunnableConfig)->output`**: 단일 입력을 처리하여 결과를 반환.
#     - **`batch(input:list, config:RunnableConfig|list[RunnableConfig]) -> list[Output]`**: 여러 입력 데이터들을 한 번에 처리.
#     - **`stream(input, config:RunnableConfig) -> Iterator[Output]`**: 입력에 대해 스트리밍 방식으로 응답을 반환.
#     - **`assign(**kwargs)`**:
#       -  앞 Runnable의 출력 결과에 새로운 key–value 쌍의 Field 추가(assign) 하여 다음 Runnable로 전달.
#       -  값으로는 Runnable 객체(LCEL체인등)나 고정 값(리터럴) 모두 가능하며, 각 항목은 실행 시 평가되어 기존 출력에 병합한다.
#       -  주로 앞 단계의 출력에 부가 정보(field)를 추가하고자 할 때 사용한다. 특히 `RunnablePassthrough`와 결합해, 입력을 그대로 넘기면서 특정 field만 추가할 때 자주 사용
# ### Runnable의 주요 구현체(하위 클래스)
#
# - **`RunnableSequence`**
#     - 여러 `Runnable`을 순차적으로 연결하여 실행하는 구성이다.
#     - 각 단계의 출력이 다음 단계의 입력으로 전달된다.
#     - 보통은 LCEL 문법을 사용해서 정의한다.
#       - LCEL을 사용하여 체인을 구성할 경우 자동으로 `RunnableSequence`로 변환된다.
#
# -  **`RunnablePassthrough`**
#     - 입력 데이터를 가공하지 않고 그대로 다음 단계로 전달하는 `Runnable`이다.
#       - 앞 Runnable으로 부터 전달 받은 **입력 값을 다음 Runnable로 그대로 전달**한다.
#            - `RunnablePassthrough()`
#       - 입력받은 값에 **Field를 추가**해서 전달할 경우 `assign()` 메소드를 사용한다.
#            - `RunnablePassthrough.assign(new_key1="new_value1", new_key2="new_value2", ..)`
#
# - **`RunnableParallel`**
#     - 여러 `Runnable`을 병렬로 실행한 후, 결과를 결합하여 다음 단계로 전달한다.
#     -
#         ```python
#         RunnableParallel(
#             {
#                 "key1":Runnable1,
#                 "key2":Runnable2,
#                 "key3":Runnable3, ...
#             }
#         )
#         ```
#       - 각 Runnable의 실행결과를 Value로 Dictionary를 생성해서 반환한다.
#       - LCEL로 정의할 때는 Chain에 dictionary로 정의한다.
#
# - **`RunnableLambda`**
#     - 일반 함수를 `Runnable`로 변환할 때 사용한다.
#
#     - Runnable을 입력해야 하는 자리에 함수를 넣어야 하는 경우 RunnableLambda로 그 함수를 Runnable로 만들어 넣는다.
#     - **구현**
#       1. `RunnableLambda(함수객체)`
#       2. `@chain` decorator를 이용해 함수를 `RunnableLamda`로 구현할 수있다.
#       3. LCEL 에 함수를 포함시키면 `RunnableLambda`로 자동 변환된다.

# %% [markdown]
# #### Runnable 예제

# %%
from langchain_core.runnables import Runnable

class MyRunnable(Runnable):
    # invoke(), stream(), batch(), assign() 중에서 필요한 메소드를 재정의.
    def invoke(self, input_data, config=None):
        # input_data : 처리를 위한 입력값. 1개. 여러개면 리스트로 묶어야됨.
        # config: RunnableConfig -> 입력시에는 dict
        # Runnable이 실행할 때 필요한 설정정보를 입력.
        #   - {"Configurable":{key: value}}
        output = ""
        if config is not None:
            if config['configurable'].get("lang") == "en":
                output = "\n\n답변은 영어로 해주세요."
        
        return f"{input_data}에 대해서 한 문장으로 정의해주세요.{output}"

# %%
mr1 = MyRunnable()
print(mr1.invoke('사과'))
print(mr1.invoke("컴퓨터", {"configurable":{"lang":"en"}}))
# Out:
# 사과에 대해서 한 문장으로 정의해주세요.
# 컴퓨터에 대해서 한 문장으로 정의해주세요.
#
# 답변은 영어로 해주세요.

# %%
# chain
chain = mr1 | model
res = chain.invoke("사과", {"configurable":{"lang":"en"}})
print(res.content)
# Out:
# An apple is the pomaceous fruit of the apple tree (Malus domestica), typically round, crisp, and sweet-to-tart in flavor, commonly eaten raw or used in cooking and baking.

# %% [markdown]
# #### RunnableLambda 예제

# %%
from langchain_core.runnables import RunnableLambda

mr2 = RunnableLambda(lambda input_data : f"{input_data}를 한문장으로 설명해줘.")
isinstance(mr2, Runnable)
# Out:
# True

# %%
query = mr2.invoke("LLM")
res = (mr2|model).invoke("LLM")
# Out:
# AIMessage(content='LLM(대형 언어 모델)은 대규모 텍스트를 학습해 문맥에 맞는 단어(토큰)를 확률적으로 예측·생성하여 자연어 이해·생성, 번역, 요약 등 다양한 언어 작업을 수행하는 인공지능 모델입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 202, 'prompt_tokens': 17, 'total_tokens': 219, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CnyCquMjLLsHDij9lGqvxiC6RlqvL', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b2f53-2f92-7be1-a90a-0032f15384e8-0', usage_metadata={'input_tokens': 17, 'output_tokens': 202, 'total_tokens': 219, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}})

# %%
def sum(input_data):
    return input_data + 100
mr3 = RunnableLambda(sum)
query = mr3.invoke(9999)
print(query)
# Out:
# 10099

# %%
# Runnable로 만들 함수
# 파라미터: 1개
# 반환값 : 다음 체인구성에 전달할 값의 형식.

# %%
prompt = ChatPromptTemplate.from_template(
    template="{subject}에 대해 100글자 이내로 설명해줘."
)
model = ChatOpenAI(model="gpt-5-mini")
parser = StrOutputParser()

# 출력결과, 글자수
chain = prompt | model | parser | RunnableLambda(lambda input_data: (input_data, len(input_data)))
res = chain.invoke({"subject":"AI Agent 구성요소"})

# %%
print(res)
# Out:
# ('지각(센서), 상태·메모리, 목표·보상, 계획·정책, 실행·액터, 학습 모듈.', 43)

# %%
def get_length(value):
    return value, len(value)

chain2 = prompt | model | parser | get_length # get_length가 내부적으로 Runnable로 바뀜.
res = chain.invoke({"subject":"AI Agent 원리"})
print(res)
# Out:
# ('환경을 인식해 모델·정책으로 계획·행동하고 보상으로 학습해 목표 달성.', 39)

# %% [markdown]
# #### RunnablePassThrough 예제

# %%
from langchain_core.runnables import RunnablePassthrough

rp = RunnablePassthrough()
res = rp.invoke("안녕하세요")
res = rp.invoke({"a":10, "b":20})
print(res)
# Out:
# {'a': 10, 'b': 20}

# %%
# 입력받은 값에 field를 추가해서 전달. 입력: dict, item을 추가해서 전달

address_runnable = RunnableLambda(lambda x: "서울시 금천구")
phone_runnable = RunnableLambda(lambda x: "010-1234-5678")

rp2 = RunnablePassthrough.assign(
    address=address_runnable, phone=phone_runnable
    #변수=Runnable(Callable) key:변수-Value:Runnable 반환값을 input dict에 추가.s
)
res = rp2.invoke({"name":"홍길동"})
res
# Out:
# {'name': '홍길동', 'address': '서울시 금천구', 'phone': '010-1234-5678'}

# %% [markdown]
# #### RunnableParallel 예제

# %%
from langchain_core.runnables import RunnableParallel

run1 = RunnableLambda(lambda x : x + 10)
run2 = RunnableLambda(lambda x : x * 10)
run3 = RunnableLambda(lambda x : x ** 10)

parallel = RunnableParallel(
    {
        "value1":run1, #run1의 실행결과를 "value1" key에 담아서 반환.
        "value2":run2,
        "value3":run3,
        "value4":RunnablePassthrough() # value4:입력값
    }
)
res = parallel.invoke(2)
res
# Out:
# {'value1': 12, 'value2': 20, 'value3': 1024, 'value4': 2}

# %%
from operator import itemgetter
# chain = RunnableLambda(lambda x : x['v1']) | parallel
chain = itemgetter('v1') | parallel
res = chain.invoke({"v1":10, "v2":20})
res
# Out:
# {'value1': 20, 'value2': 100, 'value3': 10000000000, 'value4': 10}

# %%
from operator import itemgetter

ig = itemgetter('v2') # 자료구조에서 "v1" 값을 조회
d = {"v1":10, "v2":20}
ig(d)

ig2 = itemgetter(2) # 자료구조[2] 조회한 결과를 반환.
ig2([1,2,3,4])
ig2((10,20,30,40))
# Out:
# 30

# %%
# LCEL Chain안에서 RUnnableParellel 표현식. {key:Runnable}
chain = run1 | {'result1':run2, "result2":run3}
chain.invoke(20)
# Out:
# {'result1': 300, 'result2': 590490000000000}

# %%
# {}와 Runnable이 '|'로 묶이면 {}이 Runnable
chain = {'result1':run2, "result2":run3} | RunnablePassthrough()
chain.invoke(2)
# Out:
# {'result1': 20, 'result2': 1024}

# %%
rp = {'result1':run2, "result2":run3} # 이건 그냥 딕셔너리다. invoke가 안된다.
rp.invoke()

# %% [markdown]
# ### LCEL Chain 예제

# %%
# 입력 : 음식 이름
# 출력 : 음식의 레시피
# chain : prompt_template -> model(gpt-5-mini) -> StrOutputParser

# %%
from dotenv import load_dotenv
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser

load_dotenv()

prompt = ChatPromptTemplate.from_template(
    template=""" # Instrunction
당신은 숙련된 요리 전문 assistant 입니다.
요청한 음식의 레시피를 자세하게 작성해 주세요.

# Input Data
음식이름: {food}

# Output Indicator
- markdown 형식으로 작성한다.
- 다음 항목들을 넣어 레시피를 작성한다.
    - 요리 이름
    - 요리 기본 정보
        - 난이도
        - 조리시간
        - 인분
    - 재료
    - 요리 방법
    - 팁
"""
)
model = ChatOpenAI(model="gpt-5-mini")
parser = StrOutputParser()

recipe_chain = prompt | model | parser
res = recipe_chain.invoke({"food":"바스크치즈케이크"})

# %%
print(res)
# Out:
# # 요리 이름
# 순두부찌개
#
# # 요리 기본 정보
# - 난이도: 중간
# - 조리시간: 총 25–35분 (준비 10–15분 / 조리 15–20분)
# - 인분: 2–3인분
#
# # 재료
# (기본 조합 — 돼지고기 버전)
# - 순두부 1봉(약 300–400g)
# - 돼지고기(다진 목살 또는 얇게 썬 삼겹/목살) 100g
# - 양파 1/2개 (작게 썰기)
# - 대파 1대 (송송 썰기)
# - 마늘 2–3쪽 (다진 것)
# - 청양고추 1개(선택, 어슷썰기)
# - 고춧가루 1–1.5 큰술
# - 고추장 1 작은술(선택, 더 깊은 맛 원할 때)
# - 간장 또는 국간장 1 큰술
# - 소금, 후추 약간
# - 식용유 1 큰술
# - 참기름 1 작은술
# - 계란 1개
# - 멸치·다시마 육수 600ml(약 3컵) — 없으면 물 사용 가능
#
# (해산물 버전 대체 재료)
# - 조개류(바지락/조개) 120–150g, 새우 6–8마리 등
# - 돼지고기 대신 해산물 사용 시 멸치육수 필수
#
# (채식 버전)
# - 멸치·육수 대신 다시마+표고버섯 우린 육수 사용, 고기·해산물 생략
#
# # 요리 방법
# 1. 육수 준비
#    - 멸치·다시마 육수: 냄비에 물 800ml에 마른 멸치(頭·내장 제거) 10마리, 다시마 한 장을 넣고 중불로 5–8분 끓인 뒤 다시마는 꺼내고 약한 불로 2–3분 더 끓여 체에 걸러 600ml 준비.
#    - 간편할 경우 물 600ml 사용 가능(맛은 다소 약함).
#
# 2. 재료 손질
#    - 돼지고기: 한입 크기로 썰거나 다진 것 준비.
#    - 양파, 마늘, 대파, 청양고추 손질. 순두부는 봉지째로 숟가락으로 떠낼 준비.
#
# 3. 베이스 향내 내기
#    - 뚝배기(또는 냄비)에 식용유 1큰술과 참기름 조금을 두르고 중불에서 돼지고기를 넣어 겉면이 익을 때까지 볶는다.
#    - 다진 마늘과 양파를 넣고 투명해질 때까지 볶는다.
#
# 4. 고춧가루 기름에 볶기(향 살리기)
#    - 불을 약간 줄이고 고춧가루 1–1.5큰술과 고추장 1작은술(사용 시)을 넣어 볶아 기름에 고추기름을 내준다. 타지 않도록 재빨리 섞는다.
#
# 5. 육수 붓기 및 끓이기
#    - 준비한 육수 600ml를 부어 센 불로 올려 끓인다. 끓어오르면 거품(불순물)을 걷어낸다.
#
# 6. 순두부 넣기
#    - 국물이 팔팔 끓으면 숟가락으로 순두부를 떠서 덩어리째 넣는다. (부드러운 순두부는 과도하게 저으면 부서짐)
#    - 약불로 줄여 3–5분 정도 은근히 끓여 맛을 우려낸다.
#
# 7. 간맞추기 및 마무리
#    - 간장(또는 국간장) 1큰술과 소금·후추로 간을 맞춘다.
#    - 해산물 버전은 이때 조개/새우를 넣고 조개가 입을 벌릴 때까지 익힌다.
#    - 불을 끄기 직전 계란 1개를 가운데에 톡 깨서 넣고 뚜껑을 덮어 취향에 따라 반숙(1분 내외) 또는 완숙으로 익힌다.
#    - 대파, 청양고추를 올려 한소끔(약 30초) 더 두었다가 불을 끈다.
#
# 8. 서빙
#    - 뚝배기에 담아 바로 식탁으로. 갓 지은 밥과 함께 낸다.
#
# # 팁
# - 순두부는 부드러워서 저을수록 흐트러집니다. 덜 섞을수록 식감이 살아납니다.
# - 고춧가루를 기름에 살짝 볶아 향을 내면 풍미가 훨씬 좋아집니다. (타지 않게 불을 약하게)
# - 육수 맛이 찌개의 품질을 좌우합니다. 멸치·다시마 육수를 사용하면 깊은 맛이 납니다. 멸치 내장 제거(비린내 방지)를 권장합니다.
# - 해산물(바지락 등)은 깨끗이 해감하고, 조개를 넣을 경우 끝부분(마무리)에 넣어 과도하게 익히지 마세요.
# - 기호에 따라 고추장 한 작은술을 넣으면 감칠맛과 색감이 좋아집니다.
# - 더 깔끔한 국물 원하면 기름을 식초 한 방울 넣어 데워 끓인 뒤 거품을 걷어내거나, 조리 초반에 냉수에 담근 돼지고기를 잠깐 데쳐 기름을 제거합니다.
# - 남은 찌개 보관은 냉장 보관(2일 권장). 재가열 시 물을 약간 넣고 팔팔 끓이면 부드러운 식감과 간이 안정됩니다.
# - 매운맛 조절: 고춧가루 양을 줄이거나 청양고추 대신 일반 고추 사용. 계란으로 매운맛을 완화할 수 있습니다.
#
# 원하시면 해산물 버전(바지락·새우) 또는 완전 채식 순두부찌개 레시피로 재구성해 드리겠습니다.

# %%
resp2 = ""
for token in chain.stream({"food":"바스크 치즈 케이크"}):
    print(token, end="")
    resp2 += token
# Out:
# # 바스크 치즈 케이크 (Burnt Basque Cheesecake)
#
# ## 요리 기본 정보
# - 난이도: 중간 (베이킹 경험이 있으면 쉬움)
# - 조리시간: 준비 15분 + 굽기 45–60분 + 식힘/냉장 4시간 이상 (하루 전 준비 권장)
# - 인분: 8인분 (지름 20cm 스프링폼 기준)
#
# ## 재료
# - 크림치즈(실온) 600g
# - 설탕 180g (약 3/4컵 + 2큰술)
# - 큰 달걀 3개 (실온)
# - 생크림(휘핑 크림) 240ml (1컵)
# - 박력분 또는 옥수수전분 15g (약 1큰술) — 질감 조절용
# - 바닐라 익스트랙 1작은술 (또는 바닐라 빈 1/2대 씨)
# - 소금 한 꼬집 (약 1/4작은술)
#
# 도구:
# - 지름 20cm 스프링폼 또는 틀
# - 파치먼트(베이킹)페이퍼 — 틀 높이보다 크게 잘라 사용
# - 전기믹서(또는 핸드믹서) 및 고무주걱
#
# (옵션) 장식: 신선한 베리, 소금 카라멜, 휘핑크림 등
#
# ## 요리 방법
# 1. 오븐 예열 및 틀 준비
#    - 오븐을 220°C(430°F)로 예열합니다. (일부 오븐은 200–220°C 권장)
#    - 스프링폼 틀 바닥과 옆면을 파치먼트로 감싸되, 페이퍼가 틀 윗부분보다 4–6cm 더 나오게 높게 세워 둡니다. 바스크 치즈케이크는 윗부분이 깊게 갈색이 나며 페이퍼가 꼭 필요합니다.
#
# 2. 크림치즈 준비
#    - 실온의 크림치즈를 큰 볼에 넣고 전기믹서로 부드럽게 풀어줍니다(뭉친 덩어리 없도록). 약 1–2분.
#
# 3. 설탕 추가 및 섞기
#    - 설탕을 넣고 크림치즈와 완전히 섞일 때까지 약 1–2분 더 휘핑합니다. 너무 오래 휘핑하면 공기가 많이 들어가므로 중간 세기로 필요 부분만 섞습니다.
#
# 4. 계란 넣기
#    - 계란을 한 번에 한 개씩 넣고, 각 계란이 거의 흡수될 때까지 저속으로 섞습니다. 과도한 공기 유입을 막기 위해 고속으로 오래 휘핑하지 마세요.
#
# 5. 생크림과 바닐라, 소금, 전분 넣기
#    - 생크림과 바닐라, 소금을 넣고 고무주걱이나 저속으로 부드럽게 섞습니다.
#    - 마지막에 박력분 또는 전분을 체로 쳐 넣고 덩어리 없이 섞습니다. 전체 반죽은 매끄럽고 약간 묽은 크림 상태여야 합니다.
#
# 6. 틀에 부어 굽기
#    - 준비한 틀에 반죽을 체에 한번 거르며 부어주면 기포 제거에 도움이 됩니다(선택 사항).
#    - 반죽을 틀에 붓고, 틀 바닥을 가볍게 탕탕 쳐 기포를 줄입니다.
#    - 예열된 오븐 중앙에 넣고 45–55분 굽습니다(20cm 기준). 윗면이 깊은 갈색(거의 탄 듯한 색)을 띠고 가운데가 약간 흔들릴 정도면 완성입니다. 24cm는 50–60분 가량 소요될 수 있습니다.
#    - 팁: 오븐이 윗열이 강하다면 40분 후 색을 보고 필요시 10–15분 더 굽거나, 너무 빠르게 탔으면 온도를 200°C로 낮춰 굽습니다.
#
# 7. 식힘 및 냉장
#    - 오븐에서 꺼내어 실온에서 1–2시간 식힙니다. 케이크가 조금 가라앉고 중앙의 흔들림도 줄어듭니다.
#    - 그 후 랩 없이(또는 느슨하게 덮어) 냉장고에 넣고 최소 4시간 이상, 가능하면 하룻밤(8시간 이상) 숙성시키면 맛과 질감이 훨씬 좋아집니다.
#
# 8. 서빙
#    - 꺼낼 때는 틀에서 파치먼트를 잡아 올리면 간단히 빠집니다. 케이크 윗면의 '탄 듯한' 크러스트가 바스크 치즈케이크의 특징입니다.
#    - 조각내어 제공하고, 원하면 신선한 베리, 카라멜 소스, 살짝 휘핑한 크림을 곁들입니다.
#
# ## 팁
# - 재료는 모두 실온으로 준비하세요. 특히 크림치즈와 계란은 실온일 때 더 매끄럽게 섞입니다.
# - 반죽을 너무 오래 고속으로 휘핑하면 공기가 많이 들어가 굽는 동안 표면이 갈라질 수 있습니다. 부드럽게, 필요한 만큼만 섞으세요.
# - 파치먼트는 틀보다 높게 설치하세요. 케이크가 부풀면서 틀 위로 올라오기 때문에 페이퍼 높이가 중요합니다.
# - 겉면이 많이 탄 듯 보여도 내부에는 크리미한 질감이 남아야 합니다. 표면의 짙은 갈색(거의 탄 색)은 정상이며 맛의 일부입니다.
# - 만약 윗면이 너무 빨리 타면 알루미늄 호일을 느슨하게 덮어 과도한 착색을 막으세요.
# - 중앙이 아주 단단하게 굳으면 과하게 익은 것이니, 약간 흔들리는 상태에서 꺼내는 것이 포인트입니다.
# - 보관: 냉장보관 시 3–5일 내 섭취 권장. 잘 포장해 냉동하면 1개월 내 사용 가능(해동 후 냉장).
#
# ## 변형 아이디어
# - 레몬 제스트 1작은술을 넣어 산미를 추가.
# - 크림치즈 일부(100–150g)를 마스카포네로 바꿔 더 부드럽게.
# - 설탕을 160g로 줄이고 상큼한 베리 소스를 곁들여 가볍게.
# - 위에 소금 카라멜을 약간 끼얹어 짭짤달콤 조합.
#
# 즐겁게 만들어 맛있게 드세요! 필요하시면 오븐 종류(가스/컨벡션)에 맞춘 굽기 온도/시간 조정도 안내해 드릴게요.

# %%
print(resp2)
# Out:
# # 크림 치즈 파스타
#
# ## 요리 기본 정보
# - 난이도: 쉬움
# - 조리시간: 약 25–30분
# - 인분: 2–3인분
#
# ## 재료
# - 파스타(스파게티 또는 페투치네 추천): 200g
# - 크림치즈: 100–150g (실온에서 약간 부드럽게 한 것)
# - 생크림(선택): 100ml — 더욱 부드러운 소스를 원할 때
# - 버터: 1큰술(약 15g)
# - 올리브유: 1큰술
# - 마늘: 2쪽(다진 것)
# - 양파: 1/2개(얇게 다진 것, 선택)
# - 파르미지아노·레지아노(파마산) 치즈: 30–50g(갈아놓은 것)
# - 소금: 파스타 삶는 물에 넉넉히(끓는 물 1L당 소금 약 10g 권장) + 간 맞출 때 약간
# - 흑후추: 약간(갓 갈아 사용 권장)
# - 넛맥(옵션): 아주 약간(한 꼬집)
# - 파스타 삶은 물: 약 1컵(약 200–250ml) — 소스 농도 조절용으로 꼭 남겨둔다
# - 파슬리나 쪽파(장식용): 약간
# - 레몬 제스트 또는 레몬즙(옵션, 산미 추가): 약간
# - 추가 옵션 재료 (원하면)
#   - 베이컨/판체타: 50–80g(잘게 썰어 바삭하게)
#   - 버섯: 100g(슬라이스)
#   - 시금치 한 줌
#
# ## 요리 방법
# 1. 준비
#    - 크림치즈는 미리 실온에 꺼내 두어 부드럽게 만든다(녹이기 쉬움).
#    - 파르미지아노는 갈아둔다.
#    - 마늘·양파 등 필요한 재료는 다진다.
#
# 2. 파스타 삶기
#    - 큰 냄비에 물을 넣고 강하게 끓인다. 물이 팔팔 끓으면 소금을 넉넉히 넣고 파스타를 넣어 포장지에 적힌 시간보다 1분 정도 덜 삶아 알덴테(살짝 덜 익음)로 건진다.
#    - 파스타를 건질 때 병아리 훌쩍 떠오르는 정도로 약 1컵(200–250ml) 정도의 삶은 물을 따로 덜어둔다(소스 농도 조절용).
#
# 3. 소스 베이스 만들기
#    - 팬(중간 크기)에 올리브유 1큰술과 버터 1큰술을 넣고 중약불로 가열한다.
#    - (베이컨/판체타 사용 시) 베이컨을 넣고 바삭하게 구워 꺼내 놓고, 남은 기름으로 진행한다.
#    - 다진 양파를 넣고 투명해질 때까지 약 3–4분간 볶는다.
#    - 다진 마늘을 넣고 향이 올라올 때까지 30초~1분 볶는다(마늘 태우지 않도록 주의).
#
# 4. 크림치즈 녹이기 및 소스 만들기
#    - 팬 불을 약불~중약불로 낮춘다. (너무 센 불은 크림치즈가 분리될 수 있음)
#    - 크림치즈를 큐브 형태로 잘라 팬에 넣고 숟가락으로 부드럽게 저어가며 녹인다.
#    - 생크림을 사용하는 경우 이때 넣고 섞는다. 생크림이 없으면 삶은 물로 점도를 조절한다.
#    - 소스가 되직하게 되면 파스타 삶은 물을 조금씩(필요 시) 넣어가며 원하는 농도로 맞춘다. (따뜻한 물을 조금씩 넣어 유화시킨다)
#    - 파르미지아노 치즈 2/3 분량을 넣고 잘 저어 크림과 치즈가 잘 섞이게 한다.
#    - 소금과 흑후추로 간을 맞추고, 원하면 넛맥 한 꼬집을 더한다.
#
# 5. 파스타와 소스 합치기
#    - 삶아둔 파스타를 팬에 넣고 소스와 함께 센 불(중강불)로 30초~1분 정도 빠르게 버무리며 파스타 표면에 소스가 잘 코팅되게 한다. 이때 필요하면 삶은 물을 약간 추가해 농도를 맞춘다.
#    - (베이컨/버섯/시금치 사용 시) 미리 조리해 둔 베이컨/버섯을 합치고 시금치는 마지막에 넣어 숨이 죽게 섞는다.
#    - 맨 마지막에 남겨둔 파르미지아노를 뿌려 한 번 더 섞고 불을 끈다.
#
# 6. 플레이팅 및 마무리
#    - 그릇에 담고 갓 간 흑후추, 다진 파슬리 또는 쪽파, 레몬 제스트 약간을 뿌려 마무리한다.
#    - 필요하면 올리브오일 한 방울이나 파마산 추가로 풍미를 더한다.
#
# ## 팁
# - 크림치즈 사용 팁
#   - 크림치즈는 실온에 미리 꺼내 부드럽게 해두면 녹이기 쉽고 소스가 매끄럽게 된다.
#   - 토막내어 넣고 낮은 불에서 천천히 젓는 것이 분리 방지에 도움이 된다.
#
# - 소스 농도 조절
#   - 파스타 삶은 물(전분 함유)을 조금씩 넣어가며 유화하면 소스가 부드럽고 잘 코팅된다.
#   - 생크림을 조금 더 넣으면 더 진하고 부드러운 소스가 되며, 가벼운 버전을 원하면 우유+녹인 크림치즈로 대신 가능(우유만 사용 시 소스가 묽어지므로 전분 또는 약간의 파마산으로 농도 조절).
#
# - 열 관리
#   - 크림치즈와 유제품은 높은 열에서 분리(오일과 고형분이 분리)되기 쉽다. 중약불 이하에서 천천히 녹이고, 필요한 경우 불을 끄고 잔열로 섞어 마무리하면 안정적이다.
#
# - 풍미 추가
#   - 레몬 제스트나 레몬즙을 아주 약간 넣으면 느끼함이 줄고 맛이 산뜻해진다.
#   - 베이컨, 버섯, 시금치, 구운 토마토 등과 잘 어울린다.
#   - 화이트 와인 1–2큰술로 데글레이즈 하면 향이 살아난다.
#
# - 보관 및 재가열
#   - 냉장 보관: 2일 이내 소비 권장.
#   - 재가열 시 전자레인지나 팬에 우유 또는 물을 소량(1–2큰술) 추가해 낮은 열로 천천히 데우면 소스 분리 없이 재현 가능.
#
# - 치즈 선택
#   - 파르미지아노·레지아노(파마산) 대신 페코리노 로마노를 사용하면 좀 더 강한 풍미가 난다. 블렌드도 추천.
#
# 즐겁게 요리하시고, 원하시면 베이컨/새우/버섯 등 넣은 변형 레시피도 따로 자세히 알려드릴게요.

# %%
# TODO
## 입력: 번역할 내용, 언어
## 출력: "번역할 내용"을 해당 "언어"로 번역한 결과
# 
# 입력 : {"content":"안녕하세요", "language":"영어"}
# 출력 : Hi
from dotenv import load_dotenv
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser

load_dotenv()

prompt_trans = ChatPromptTemplate.from_template(
    template=""" # Instrunction
당신은 외계어와 다국어가 가능한 순련된 번역 전문 assistant 입니다.
번역할 내용을 번역할 언어로 번역해 주세요.

# Input Data
번역할 내용: {content}
번역할 언어: {language}
"""
)
model = ChatOpenAI(model="gpt-5-mini")
parser = StrOutputParser()

translate_chain = prompt_trans | model | parser
translate_res = translate_chain.invoke({"content":"감사합니다", "language":"화성어"})

# %%
print(translate_res)
# Out:
# Thra'kesh

# %%
resp2
# Out:
# '# 크림 치즈 파스타\n\n## 요리 기본 정보\n- 난이도: 쉬움\n- 조리시간: 약 25–30분\n- 인분: 2–3인분\n\n## 재료\n- 파스타(스파게티 또는 페투치네 추천): 200g  \n- 크림치즈: 100–150g (실온에서 약간 부드럽게 한 것)  \n- 생크림(선택): 100ml — 더욱 부드러운 소스를 원할 때  \n- 버터: 1큰술(약 15g)  \n- 올리브유: 1큰술  \n- 마늘: 2쪽(다진 것)  \n- 양파: 1/2개(얇게 다진 것, 선택)  \n- 파르미지아노·레지아노(파마산) 치즈: 30–50g(갈아놓은 것)  \n- 소금: 파스타 삶는 물에 넉넉히(끓는 물 1L당 소금 약 10g 권장) + 간 맞출 때 약간  \n- 흑후추: 약간(갓 갈아 사용 권장)  \n- 넛맥(옵션): 아주 약간(한 꼬집)  \n- 파스타 삶은 물: 약 1컵(약 200–250ml) — 소스 농도 조절용으로 꼭 남겨둔다  \n- 파슬리나 쪽파(장식용): 약간  \n- 레몬 제스트 또는 레몬즙(옵션, 산미 추가): 약간  \n- 추가 옵션 재료 (원하면)\n  - 베이컨/판체타: 50–80g(잘게 썰어 바삭하게)  \n  - 버섯: 100g(슬라이스)  \n  - 시금치 한 줌\n\n## 요리 방법\n1. 준비  \n   - 크림치즈는 미리 실온에 꺼내 두어 부드럽게 만든다(녹이기 쉬움).  \n   - 파르미지아노는 갈아둔다.  \n   - 마늘·양파 등 필요한 재료는 다진다.\n\n2. 파스타 삶기  \n   - 큰 냄비에 물을 넣고 강하게 끓인다. 물이 팔팔 끓으면 소금을 넉넉히 넣고 파스타를 넣어 포장지에 적힌 시간보다 1분 정도 덜 삶아 알덴테(살짝 덜 익음)로 건진다.  \n   - 파스타를 건질 때 병아리 훌쩍 떠오르는 정도로 약 1컵(200–250ml) 정도의 삶은 물을 따로 덜어둔다(소스 농도 조절용).\n\n3. 소스 베이스 만들기  \n   - 팬(중간 크기)에 올리브유 1큰술과 버터 1큰술을 넣고 중약불로 가열한다.  \n   - (베이컨/판체타 사용 시) 베이컨을 넣고 바삭하게 구워 꺼내 놓고, 남은 기름으로 진행한다.  \n   - 다진 양파를 넣고 투명해질 때까지 약 3–4분간 볶는다.  \n   - 다진 마늘을 넣고 향이 올라올 때까지 30초~1분 볶는다(마늘 태우지 않도록 주의).\n\n4. 크림치즈 녹이기 및 소스 만들기  \n   - 팬 불을 약불~중약불로 낮춘다. (너무 센 불은 크림치즈가 분리될 수 있음)  \n   - 크림치즈를 큐브 형태로 잘라 팬에 넣고 숟가락으로 부드럽게 저어가며 녹인다.  \n   - 생크림을 사용하는 경우 이때 넣고 섞는다. 생크림이 없으면 삶은 물로 점도를 조절한다.  \n   - 소스가 되직하게 되면 파스타 삶은 물을 조금씩(필요 시) 넣어가며 원하는 농도로 맞춘다. (따뜻한 물을 조금씩 넣어 유화시킨다)  \n   - 파르미지아노 치즈 2/3 분량을 넣고 잘 저어 크림과 치즈가 잘 섞이게 한다.  \n   - 소금과 흑후추로 간을 맞추고, 원하면 넛맥 한 꼬집을 더한다.\n\n5. 파스타와 소스 합치기  \n   - 삶아둔 파스타를 팬에 넣고 소스와 함께 센 불(중강불)로 30초~1분 정도 빠르게 버무리며 파스타 표면에 소스가 잘 코팅되게 한다. 이때 필요하면 삶은 물을 약간 추가해 농도를 맞춘다.  \n   - (베이컨/버섯/시금치 사용 시) 미리 조리해 둔 베이컨/버섯을 합치고 시금치는 마지막에 넣어 숨이 죽게 섞는다.  \n   - 맨 마지막에 남겨둔 파르미지아노를 뿌려 한 번 더 섞고 불을 끈다.\n\n6. 플레이팅 및 마무리  \n   - 그릇에 담고 갓 간 흑후추, 다진 파슬리 또는 쪽파, 레몬 제스트 약간을 뿌려 마무리한다.  \n   - 필요하면 올리브오일 한 방울이나 파마산 추가로 풍미를 더한다.\n\n## 팁\n- 크림치즈 사용 팁\n  - 크림치즈는 실온에 미리 꺼내 부드럽게 해두면 녹이기 쉽고 소스가 매끄럽게 된다.  \n  - 토막내어 넣고 낮은 불에서 천천히 젓는 것이 분리 방지에 도움이 된다.\n\n- 소스 농도 조절\n  - 파스타 삶은 물(전분 함유)을 조금씩 넣어가며 유화하면 소스가 부드럽고 잘 코팅된다.  \n  - 생크림을 조금 더 넣으면 더 진하고 부드러운 소스가 되며, 가벼운 버전을 원하면 우유+녹인 크림치즈로 대신 가능(우유만 사용 시 소스가 묽어지므로 전분 또는 약간의 파마산으로 농도 조절).\n\n- 열 관리\n  - 크림치즈와 유제품은 높은 열에서 분리(오일과 고형분이 분리)되기 쉽다. 중약불 이하에서 천천히 녹이고, 필요한 경우 불을 끄고 잔열로 섞어 마무리하면 안정적이다.\n\n- 풍미 추가\n  - 레몬 제스트나 레몬즙을 아주 약간 넣으면 느끼함이 줄고 맛이 산뜻해진다.  \n  - 베이컨, 버섯, 시금치, 구운 토마토 등과 잘 어울린다.  \n  - 화이트 와인 1–2큰술로 데글레이즈 하면 향이 살아난다.\n\n- 보관 및 재가열\n  - 냉장 보관: 2일 이내 소비 권장.  \n  - 재가열 시 전자레인지나 팬에 우유 또는 물을 소량(1–2큰술) 추가해 낮은 열로 천천히 데우면 소스 분리 없이 재현 가능.\n\n- 치즈 선택\n  - 파르미지아노·레지아노(파마산) 대신 페코리노 로마노를 사용하면 좀 더 강한 풍미가 난다. 블렌드도 추천.\n\n즐겁게 요리하시고, 원하시면 베이컨/새우/버섯 등 넣은 변형 레시피도 따로 자세히 알려드릴게요.'

# %%
resp3 = translate_chain.invoke({"content":resp2, "language":"영어"})

# %%
print(resp3)
# Out:
# Cream Cheese Pasta
#
# Basic information
# - Difficulty: Easy
# - Cooking time: About 25–30 minutes
# - Servings: 2–3
#
# Ingredients
# - Pasta (spaghetti or fettuccine recommended): 200 g
# - Cream cheese: 100–150 g (softened slightly at room temperature)
# - Heavy cream (optional): 100 ml — for a creamier sauce
# - Butter: 1 tbsp (about 15 g)
# - Olive oil: 1 tbsp
# - Garlic: 2 cloves (minced)
# - Onion: 1/2 (thinly chopped, optional)
# - Parmigiano-Reggiano (Parmesan) cheese: 30–50 g (grated)
# - Salt: plenty for the pasta cooking water (about 10 g per 1 L of boiling water recommended) + a little for seasoning
# - Black pepper: to taste (freshly ground recommended)
# - Nutmeg (optional): a very small pinch
# - Pasta cooking water: about 1 cup (200–250 ml) — reserve for adjusting sauce consistency
# - Parsley or scallions (for garnish): a little
# - Lemon zest or lemon juice (optional, for brightness): a little
# - Optional add-ins (if desired)
#   - Bacon/pancetta: 50–80 g (cut into small pieces and cooked until crispy)
#   - Mushrooms: 100 g (sliced)
#   - A handful of spinach
#
# Method
# 1. Preparation
#    - Take the cream cheese out ahead of time so it softens at room temperature (this makes it easier to melt).
#    - Grate the Parmigiano-Reggiano.
#    - Chop the garlic, onion, and any other ingredients you’ll use.
#
# 2. Cook the pasta
#    - Bring a large pot of water to a rolling boil. When boiling, add plenty of salt and the pasta. Cook the pasta about 1 minute less than the package time so it’s al dente.
#    - When draining the pasta, reserve about 1 cup (200–250 ml) of the cooking water for adjusting the sauce.
#
# 3. Make the sauce base
#    - In a medium pan, heat 1 tbsp olive oil and 1 tbsp butter over medium-low heat.
#    - (If using bacon/pancetta) Cook the bacon until crispy, remove and set aside, and continue with the remaining fat in the pan.
#    - Add the chopped onion and sauté about 3–4 minutes until translucent.
#    - Add the minced garlic and cook 30 seconds to 1 minute until fragrant (avoid burning the garlic).
#
# 4. Melt the cream cheese and finish the sauce
#    - Reduce the heat to low–medium (too high can cause the cream cheese to separate).
#    - Cut the cream cheese into cubes and add to the pan, stirring gently with a spoon to melt.
#    - If using heavy cream, add it now and mix. If not using cream, use the reserved pasta water to adjust consistency.
#    - Once the sauce is thick and creamy, add reserved pasta water a little at a time as needed to reach the desired consistency (warm water helps emulsify).
#    - Stir in about two-thirds of the grated Parmigiano-Reggiano until the cheese and cream are well combined.
#    - Season with salt and freshly ground black pepper, and add a pinch of nutmeg if desired.
#
# 5. Combine pasta and sauce
#    - Add the drained pasta to the pan and toss over medium-high heat for 30 seconds to 1 minute so the sauce coats the pasta well. Add a splash of reserved pasta water if needed to adjust the texture.
#    - (If using bacon/mushrooms/spinach) Add the cooked bacon and mushrooms, and stir in the spinach at the end just until wilted.
#    - Sprinkle the remaining Parmigiano-Reggiano on top, give it one more stir, and turn off the heat.
#
# 6. Plating and finishing
#    - Serve on plates and finish with freshly ground black pepper, chopped parsley or scallions, and a little lemon zest.
#    - Optionally add a drizzle of olive oil or extra Parmesan for more flavor.
#
# Tips
# - Cream cheese tips
#   - Soften cream cheese at room temperature beforehand for easier melting and a smoother sauce.
#   - Cut into pieces and melt slowly over low heat while stirring to help prevent separation.
#
# - Sauce consistency
#   - Gradually add reserved pasta water (contains starch) to emulsify and create a silky sauce.
#   - Use more heavy cream for a richer, creamier sauce. For a lighter version, you can use milk plus melted cream cheese, but milk alone may thin the sauce—adjust thickness with starch or extra Parmesan.
#
# - Heat control
#   - Dairy can separate at high heat. Melt cream cheese over low–medium heat and finish with residual heat if needed.
#
# - Flavor additions
#   - A little lemon zest or juice brightens the dish and cuts richness.
#   - Bacon, mushrooms, spinach, or roasted tomatoes pair well.
#   - Deglazing the pan with 1–2 tbsp dry white wine can add extra aroma.
#
# - Storage and reheating
#   - Refrigerate and consume within 2 days.
#   - Reheat gently in a microwave or skillet with 1–2 tbsp milk or water over low heat to prevent separation.
#
# - Cheese options
#   - Pecorino Romano can be used instead of Parmigiano-Reggiano for a stronger flavor, or try a blend.
#
# Enjoy cooking. If you like, I can provide detailed variation recipes with bacon, shrimp, mushrooms, etc.

# %% [markdown]
# ### Chain과 Chain간의 연결

# %%
type(chain)

# %%
# recipe_chain - translate_chain(연결)
# 음식 레시피를 원하는 언어로 출력.
# recipe_chain : 입력 - food: 음식이름
# translate_chain : 입력 - content: 번역할 내용, language: 언어

# %%
from operator import itemgetter
# chain입력: {food:음식이름, language: 언어}
# 첫번째 chain:food
# language는 두번째 chain으로 넘겨야 한다.
# 첫번째 chain의 출력결과를 content로 두번째 chain으로 넘긴다.
chain = {
    "content":recipe_chain,
    "language":itemgetter("language")
} | translate_chain

result = chain.invoke({"food":"바스크치즈케이크", "language":"영어"})

# 첫번째 문제. 체인들이 입력이 다름.
# c.invoke({"food":"된장찌개", "language":"영어", "content":"번역할 내용"})
# 두번째 문제
# 인자들이 첫번째 체인으로만 다 들어감. 두번쨰 체인으로는 안들어감.

# %%
# print(result)
from IPython.display import Markdown
Markdown(result)
# Out:
# # Basque Burnt Cheesecake
#
# Basic info
# - Difficulty: Medium
# - Time: Prep 15–25 minutes / Bake 45–55 minutes / Chill at least 4 hours (recommended: overnight) — total about 5 hours or more
# - Serves: 6–8 (20 cm / 8-inch cake pan)
#
# Ingredients
# - Cream cheese (full-fat, block) 500 g, at room temperature
# - Sugar 160 g
# - Large eggs 4, at room temperature
# - Heavy cream (35% fat or higher) 300 ml, at room temperature
# - Cake flour (or all-purpose flour) 20 g (about 2 tablespoons) — alternative: replace with 10 g cornstarch
# - Vanilla extract 1 teaspoon (or a little vanilla bean)
# - A pinch of salt (about 1/4–1/2 teaspoon)
# - (Optional) A little lemon zest — if you want brightness
#
# Additional equipment: about a 20 cm (8-inch) springform or cake pan, baking paper (line it high)
#
# Oven temperature reference: 210°C (about 410°F). If needed, use 200–220°C (390–430°F) depending on your oven.
#
# Method
# 1. Preheat oven and prepare pan
#    - Preheat the oven to 210°C (adjust between 200–220°C / 390–430°F depending on your oven).
#    - Line the inside of the pan with baking paper, letting it rise well above the rim (paper should extend 5–8 cm / 2–3 in higher than the pan). You don’t need to fold or tape the paper; it will flatten during baking.
#
# 2. Bring ingredients to room temperature
#    - Take the cream cheese, eggs, and heavy cream out in advance so they are not cold (this helps avoid lumps).
#
# 3. Mix cream cheese and sugar
#    - Put the room-temperature cream cheese in a large bowl and soften it with a rubber spatula or hand mixer. Add the sugar and mix until smooth (use medium speed if using a mixer).
#
# 4. Add eggs one at a time
#    - Add the eggs one at a time, mixing completely after each addition. Adding them all at once can cause the mixture to split.
#
# 5. Add dry ingredients and flavoring
#    - Sift the cake flour (or cornstarch) and salt into the batter and fold gently with a spatula. Add vanilla and lemon zest (if using).
#
# 6. Add heavy cream and finish mixing
#    - Add the heavy cream in several additions, mixing until the texture is uniform. If using a mixer, work at low–medium speed and avoid overbeating to minimize air incorporation. The batter should be smooth and slightly loose (a viscous, creamy consistency).
#
# 7. Pour into pan and bake
#    - Pour the batter into the prepared pan and level the surface.
#    - Bake on the center rack of the preheated oven for 45–55 minutes. The surface should be a deep golden to very dark brown (sometimes nearly black) and well caramelized. The center should still jiggle slightly when shaken (a jelly-like wobble).
#
# 8. Cool and chill
#    - After baking, either crack the oven door open or remove the cake and let it cool completely in the pan at room temperature (about 1 hour). Then refrigerate for at least 4 hours, preferably overnight, so the center sets and the flavor improves.
#
# 9. Serve
#    - To remove from the pan, carefully lift the baking paper. The top will be deeply browned while the inside remains moist and creamy. Serve chilled or slightly warmed at room temperature for 20–30 minutes. Pairs well with fresh fruit, berry sauce, or caramel.
#
# Tips
# - Line the pan with baking paper higher than the rim: this prevents overflow when the batter rises and creates the characteristic deeply colored edge.
# - Bring all ingredients to room temperature: cold cream cheese makes lumps and prevents even mixing.
# - Do not overmix: incorporating too much air can make the cake rise a lot in the oven and then sink and crack when cooling.
# - Baking temperature and time: the signature “burnt” top comes from the high temperature, so bake between 200–220°C (390–430°F). If the surface browns too quickly, lower the temperature by 10–20°C and increase the bake time.
# - A slightly wobbly center at the end of baking is normal. It will set during chilling.
# - If it’s too dense: you may have overbaked or the batter was too thick. Next time shorten the bake time or lower the oven temperature.
# - Ingredient swaps: low-fat ingredients are not recommended. The rich fat content is what gives Basque cheesecake its texture.
# - Storage: Refrigerate 4–5 days. Freeze up to 1 month (thaw in the fridge before eating).
#
# Enjoy making it! If you want, I can help scale the recipe to half size (for a smaller pan) or adjust quantities for a larger pan.

# %% [markdown]
# ## 사용자 함수를 Chain에 적용하기
#
# ### 사용자 함수를 Runnable로 정의 (RunnableLambda)
# - 임의의 함수를 Runnable로 정의 할 수있다.
#   - chain에 포함할 기능을 함수로 정의할 때 주로 사용.
# - `RunnableLambda(함수)` 사용
#   - 함수는 invoke() 메소드를 통해 입력받은 값을 받을 **한개의 파라미터**를 선언해야 한다.
#   - 보통 Lambda 표현식으로 정의한 함수를 LCEL chain에 포함시킬 때 사용한다.
#
# #### Runnable 에 사용할 **사용자 정의 함수** 구문
# - 이전 Chain의 출력을 입력 받는 **파라미터를 한개** 선언한다. (첫번째 파라미터)
# - `invoke()`로 호출 할때 전달 하는 추가 설정을 입력받는 파라미터를 선언한다.(두번째 파라미터 - Optional)
#   - RunnableConfig 타입의 값을 받는데 Dictionary 형식으로 `{"configuable": {"설정이름":"설정값"}}` 형식으로 받는다.
# - 만약 함수가 여러개의 인자를 받는 경우 단일 입력을 받아들이고 이를 여러 인수로 풀어내는 래퍼 함수를 작성하여 Runnable로 만든다.
#   ```python
#   def plus(num1, num2):
#       ...
#
#   def wrapper_plus(nums:dict|list):
#       return plus(nums['num1'], nums['num2'])
#   ```
#
# ### 함수 자체를 chain에 추가
# - RunnableLambda에 전달할 함수 구문에 맞는 함수라면 RunnableLambda를 사용하지 않고 chain에 넣을 수 있다.
# - 단 함수로 정의하고 LCEL에 포함시켜야 한다. Lambda 표현식으로 작성한 함수는 `RunnableLambda`를 사용해야 한다.
#
# ### 사용자 함수를 Chain으로 정의
# - Chain 을 구성하는 작업 사이에 추가 작업이 필요할 경우, 중간 결과를 모두 사용해야 하는 경우 함수로 구현한다.
# - `@chain` 데코레이터를 사용해 함수에 선언한다.

# %%
from langchain_core.runnables import RunnableLambda, RunnablePassthrough

def plus(num1, num2):
    return num1 + num2

def wrapper_plus(num:dict|list)->int:
    return plus(num[0], num[1])

# chain = RunnablePassthrough() | wrapper_plus
chain = RunnablePassthrough() | RunnableLambda(lambda num:plus(num[0], num[1]))
chain.invoke([10, 20])
# Out:
# 30

# %%
from langchain_core.runnables import chain
# @chain:복잡한 체인구조를 정의한 함수를 Runnable로 만들때 사용.
# LCEL: 순차구조(흐름)만 정의가 가능.
# @chain 함수를 이용해서 chain 구성:조건문, 반복문을 이용해 chain의 흐름을 제어할 경우

@chain
def custom_chain(input_data:dict)->dict[str, str]:
    # input_data: food, language, kor_recipe:bool
    # kor_recipe: True 면 한국어 레시피와 language로 번역된 레시피 반환
    #           : False면 language로 번역된 레시피만 반환
    # 조건절은 LCEL 로는 구현이 안됨.
    food = input_data['food']
    language = input_data['language']
    is_kor = input_data['kor_recipe']

    korean_recipe = recipe_chain.invoke({"food":food})
    result = translate_chain.invoke(
        {"content":korean_recipe, "language":language}
    )
    if is_kor:
        return (korean_recipe, result)
    else:
        return result
res = custom_chain.invoke(
    {"food":"어남선생 리조또", "language":"영어", "kor_recipe":True})

# %%
print(res[0])
# Out:
# # 어남선생 리조또
#
# 해산물 베이스의 크리미한 리조또. 바다의 풍미를 살린 깔끔한 국물과 버터·파르메산의 조합으로 깊고 부드러운 식감을 냅니다.
#
# ## 요리 기본 정보
# - 난이도: 중간
# - 조리시간: 약 35–45분 (준비 10분, 조리 25–35분)
# - 인분: 2–3인분
#
# ## 재료
# - 쌀
#   - 아르보리오(리조또용) 쌀 200g (약 1컵)
# - 육수/국물
#   - 생선·해물 육수(또는 치킨·야채 육수) 850–900ml(따뜻하게 유지)
# - 해산물
#   - 혼합 해산물(새우, 오징어, 홍합 등) 250–300g
# - 채소/향미
#   - 양파(중) 1개 → 다진 것
#   - 마늘 2쪽 → 다진 것
#   - 올리브유 2큰술
# - 풍미/마무리
#   - 드라이 화이트 와인 100ml (없으면 육수 100ml + 식초 약간으로 대체)
#   - 버터 30g (마무리용 20g + 볶을 때 10g)
#   - 파르메산 치즈 간 것 40–60g (간 보기)
#   - 소금, 갓 간 흑후추 적당량
#   - 다진 파슬리 한 줌
#   - 레몬 1/2개 (즙 또는 제스트)
# - 선택 재료 (한국적 변주)
#   - 다시마·멸치로 만든 국물 900ml (해물 육수 대체 가능)
#   - 고추기름 또는 고춧가루 약간(매콤한 변주)
#
# ## 요리 방법
# 1. 준비
#    - 해산물은 깨끗이 씻어 물기를 빼고, 새우는 껍질을 벗긴 뒤 등 쪽 내장을 제거한다(머리/껍질은 육수 내면 풍미 좋음).
#    - 육수는 냄비에 데워 약한 불에서 따뜻하게 유지한다(끓이지 않음).
#    - 파르메산은 곱게 갈아 준비한다.
#
# 2. 해산물 전처리 (선택 사항)
#    - 해산물을 팬에 올리브유 한 작은술과 마늘 약간으로 살짝 볶아 반쯤 익힌 뒤 따로 덜어둔다. (리조또에서 해산물을 마지막에 넣어 과도한 조리를 방지)
#
# 3. 소테(향내기)
#    - 넓은 팬(또는 냄비)에 올리브유 2큰술과 버터 10g을 넣고 중약불로 가열한다.
#    - 다진 양파를 넣고 투명해질 때까지 4–5분 볶는다. 다진 마늘을 넣고 30초 더 볶아 향을 낸다.
#
# 4. 쌀 넣기(토스팅)
#    - 아르보리오 쌀을 넣고 기름과 양파에 잘 버무려 1–2분 동안 쌀 가장자리가 반투명해질 때까지 볶아 약간 토스트한다(쌀알에 코팅되어 레지스탕스가 생기면 좋다).
#
# 5. 디글레이즈(와인)
#    - 화이트 와인 100ml를 붓고 중불에서 알코올이 날아가고 액체가 거의 사라질 때까지 저어 준다. (와인 대체 시 따뜻한 육수 100ml + 식초 1작은술)
#
# 6. 국물 추가(젓기)
#    - 뜨거운 육수를 국자로 한 국자씩(약 80–100ml) 부어가며 중불에서 천천히 저어준다. 쌀이 육수를 흡수하면 다음 국자를 추가한다.
#    - 이 과정을 반복하되 한 번에 많이 붓지 말고 쌀이 알단테(중심에 아주 약간의 단단함)가 될 때까지 약 18–22분간 계속한다. 너무 자주 저어주면 쌀이 으깨질 수 있으니 1–2분 간격으로 저어 주며 확인.
#
# 7. 해산물 합체
#    - 쌀이 거의 익었을 때(마지막 2–3국자 남긴 시점 또는 알단테 상태), 따로 준비한 해산물을 팬에 넣고 2–3분간 함께 저어가며 익힌다. (홍합 등 껍데기 있는 해산물은 껍데기 열린 상태여야 함)
#
# 8. 마무리(유화)
#    - 불을 끄고 버터 20g과 간 파르메산 40–60g을 넣고 재빨리 저어 유화를 만든다. 필요하면 소금·후추로 간을 맞춘다.
#    - 레몬즙을 약간 뿌려 산도를 더하고 다진 파슬리를 섞는다.
#
# 9. 플레이팅
#    - 그릇에 담고 위에 파르메산을 약간 더 갈아 올리고 올리브오일 몇 방울, 레몬 제스트 또는 파슬리로 장식해 서빙한다.
#    - 리조또는 약간 묽고 크리미한 상태가 가장 이상적이다(냉각되면 더 걸쭉해짐).
#
# ## 팁
# - 쌀 종류: 아르보리오, 카르나롤리(가능하면 카르나롤리가 더 식감이 좋다). 일반 쌀 사용 시 질감이 달라짐.
# - 육수 온도: 따뜻한 육수를 사용하면 쌀의 조리가 일정하게 진행된다. 차가운 육수를 부으면 온도 변동으로 조리 시간이 늘어짐.
# - 저어주는 정도: 끓이듯 강하게 저어주면 전분이 과도하게 풀려 질감이 묽고 끈적해짐. 1–2분 간격으로 저어주되 팬 바닥을 긁어주는 정도로 충분.
# - 와인 대체: 화이트 와인이 없으면 육수로 대체하고 마지막에 레몬즙으로 약간 산미를 보강한다.
# - 해산물 조리: 해산물은 따로 반쯤 익혀 두었다가 마지막에 합치는 것이 과도한 조리를 막아 탱글한 식감을 유지한다.
# - 한국식 변주: 육수를 멸치·다시마로 내고 마무리에 참기름 몇 방울 또는 고추기름 약간을 더하면 한식 느낌을 살릴 수 있다.
# - 보관/재가열: 남은 리조또는 1–2일 냉장 보관. 재가열 시 우유·육수·버터를 조금 추가해 살짝 풀어가며 데우면 처음과 비슷한 크리미함을 회복한다.
# - 치즈: 파르메산 대신 페코리노를 섞으면 짭짤한 풍미가 강해진다(단, 짠맛 조절 필요).
#
# 즐겁게 요리하시고, 원하시면 채소만 사용한 베지테리언 버전이나 고추장·김치 변주 레시피도 만들어 드릴게요.

# %%
print(res[1])
# Out:
# Title: Mr. Eonam’s Seafood Risotto
#
# A creamy risotto with a seafood base. Clean broth that highlights the flavors of the sea combined with butter and Parmesan gives a deep, smooth texture.
#
# Basic information
# - Difficulty: Medium
# - Total time: about 35–45 minutes (10 minutes prep, 25–35 minutes cooking)
# - Serves: 2–3
#
# Ingredients
# - Rice
#   - Arborio (risotto) rice 200 g (about 1 cup)
# - Stock/Broth
#   - Fish/seafood stock (or chicken/vegetable stock) 850–900 ml, kept warm
# - Seafood
#   - Mixed seafood (shrimp, squid, mussels, etc.) 250–300 g
# - Vegetables/aromatics
#   - 1 medium onion → chopped
#   - 2 garlic cloves → minced
#   - Olive oil 2 tbsp
# - Flavor/finishing
#   - Dry white wine 100 ml (if unavailable, substitute 100 ml stock + about 1 tsp vinegar)
#   - Butter 30 g (10 g for sautéing + 20 g for finishing)
#   - Grated Parmesan 40–60 g (to taste)
#   - Salt and freshly ground black pepper to taste
#   - A handful of chopped parsley
#   - 1/2 lemon (juice or zest)
# - Optional (Korean variation)
#   - Kelp-and-anchovy stock 900 ml (can replace seafood stock)
#   - A little chili oil or gochugaru (Korean chili powder) for a spicy twist
#
# Method
# 1. Prep
#    - Clean the seafood and drain. Peel shrimp and remove the vein (keeping heads/shells for stock adds flavor).
#    - Warm the stock in a pot over low heat and keep it warm (do not boil).
#    - Finely grate the Parmesan.
#
# 2. Pre-cook seafood (optional)
#    - Briefly sauté the seafood in a pan with about 1 tsp olive oil and a little garlic until halfway cooked, then set aside. (This prevents overcooking when added to the risotto.)
#
# 3. Sauté aromatics
#    - In a wide pan or pot, heat 2 tbsp olive oil and 10 g butter over medium-low heat.
#    - Add the chopped onion and sauté 4–5 minutes until translucent. Add the minced garlic and cook 30 seconds until fragrant.
#
# 4. Toast the rice
#    - Add the Arborio rice and toss to coat in the fat and onions. Toast for 1–2 minutes until the edges of the grains start to look translucent.
#
# 5. Deglaze (wine)
#    - Pour in 100 ml white wine and stir over medium heat until the alcohol evaporates and the liquid has mostly reduced. (If substituting, use 100 ml warm stock + 1 tsp vinegar.)
#
# 6. Add stock (ladle by ladle)
#    - Add hot stock one ladleful at a time (about 80–100 ml), stirring occasionally over medium heat. When the rice absorbs the liquid, add the next ladle.
#    - Continue this process, adding small amounts each time rather than all at once, until the rice is al dente (slightly firm at the center), about 18–22 minutes. Avoid stirring continuously; stir every 1–2 minutes and scrape the bottom of the pan gently.
#
# 7. Combine seafood
#    - When the rice is nearly done (with 2–3 ladles of stock left or when it reaches al dente), add the prepared seafood to the pan and cook together for 2–3 minutes. Shellfish like mussels should be open when done.
#
# 8. Finish (emulsify)
#    - Turn off the heat and quickly stir in 20 g butter and 40–60 g grated Parmesan to create a creamy emulsion. Adjust seasoning with salt and pepper.
#    - Add a little lemon juice for brightness and fold in the chopped parsley.
#
# 9. Plating
#    - Serve in bowls, grate a little more Parmesan on top, drizzle a few drops of olive oil, and garnish with lemon zest or parsley.
#    - The ideal risotto texture is slightly loose and very creamy (it will thicken as it cools).
#
# Tips
# - Rice types: Arborio or Carnaroli (Carnaroli gives a better texture if available). Regular rice will give a different texture.
# - Stock temperature: Using warm stock ensures even cooking. Cold stock will slow the cooking and affect timing.
# - How much to stir: Avoid vigorous, constant stirring; that releases too much starch and makes the risotto gluey. Stir every 1–2 minutes, just enough to scrape the pan bottom.
# - Wine substitute: If you don’t have white wine, use stock and boost acidity at the end with lemon juice.
# - Seafood cooking: Pre-cooking seafood and adding it near the end prevents overcooking and keeps a firm, pleasant texture.
# - Korean variation: Use anchovy-kelp stock and finish with a few drops of sesame oil or a little chili oil for a Korean twist.
# - Storage/reheating: Keep leftovers refrigerated 1–2 days. Reheat by loosening with a little milk, stock, or butter to restore creaminess.
# - Cheese swap: Mixing in Pecorino offers a saltier, sharper flavor—adjust salt accordingly.
#
# Enjoy cooking. If you’d like a vegetarian version or a gochujang/kimchi-style variation, I can provide a recipe.

# %%
res = custom_chain.invoke(
    {"food":"어남선생 리조또", "language":"영어", "kor_recipe":False})

# %%
print(res)
# Out:
# Title: Eonam’s Risotto (Seafood Risotto)
#
# Basic information
# - Difficulty: Intermediate (requires attention to risotto texture and cooking seafood)
# - Total time: about 40 minutes (10 min prep + 30 min cooking)
# - Servings: 2–3
#
# Ingredients
# - Arborio rice (or Carnaroli) 250 g (about 1 cup + 1/4 cup)
# - Mixed seafood 300 g (e.g., shrimp 120 g, squid 100 g, mussels/clams 80 g — adjust to taste)
# - Fish/seafood stock 1.2 L (keep hot)
#   - Alternative: chicken stock (if you want more seafood flavor, make stock with shrimp shells or anchovies + kelp)
# - White wine 80–100 ml (if unavailable, substitute 100 ml chicken stock or water)
# - Onion (medium) 1, or 2 shallots (finely chopped)
# - Garlic 2 cloves (minced)
# - Olive oil 2 tbsp
# - Unsalted butter 30 g
# - Parmigiano-Reggiano (or Parmesan), grated 50 g
# - Lemon zest (optional) about 1 tsp + lemon juice about 1 tsp
# - Salt and pepper to taste
# - Chopped parsley (optional) 1 tbsp
# - (Optional) Anchovy extract or fish sauce 1/2–1 tsp — for extra umami
#
# Method
#
# 1. Preparation
# - Clean and trim the seafood and pat dry. Peel and devein shrimp. Remove beards and sand from mussels/clams.
# - Keep the stock simmering in a pot so it stays hot.
# - Finely chop the onion and garlic. Grate the Parmigiano.
#
# 2. Pre-cook seafood (optional)
# - Heat 1 tbsp olive oil in a pan and briefly sear the seafood over high heat for 1–2 minutes just to color the outside, then set aside. (Avoid overcooking; you want to prevent the seafood from becoming tough in the risotto.)
#
# 3. Make the risotto base
# - In a wide pan (or deep skillet), heat 1 tbsp olive oil and 10 g butter.
# - Add the chopped onion and cook over low heat for 3–4 minutes until translucent. Add the garlic and cook about 30 seconds until fragrant.
# - Add the rice and toss over medium heat for 1–2 minutes until the grains become slightly translucent and are well coated with fat (toasting).
#
# 4. Deglaze with wine
# - Pour in the white wine and cook about 1 minute to evaporate the alcohol and bring up the aroma. (If not using wine, add 100 ml hot stock.)
#
# 5. Add stock and stir
# - Add the hot stock ladle by ladle (about 100 ml each). When the rice absorbs the liquid, add the next ladle. Repeat this process. Cook for a total of about 18–22 minutes until the rice is al dente — slightly firm in the center.
# - Stir fairly often (every 1–2 minutes), but avoid stirring excessively. The goal is a creamy surface.
#
# 6. Add the seafood
# - When the rice is nearly done (after the last or second-to-last ladle of stock), add the pre-cooked (or raw) seafood to the risotto and cook another 3–5 minutes until the seafood is just cooked through. Mussels/clams are done when their shells open.
# - Season with salt and pepper. If you want more umami, add 1/2 tsp anchovy extract or fish sauce and adjust seasoning.
#
# 7. Finish
# - Turn off the heat and add the remaining butter (about 20 g) and 40 g grated Parmigiano. Stir quickly to emulsify and create a creamy texture (mantecatura).
# - Add a little lemon zest and lemon juice to brighten the seafood flavor.
# - Finish with chopped parsley and additional pepper if desired.
#
# 8. Serve
# - Serve immediately while hot. Optionally grate extra Parmigiano on top and serve with lemon wedges.
#
# Tips
# - Rice choice: Use risotto rice (Arborio, Carnaroli, Vialone Nano). Regular rice won’t produce the same creaminess.
# - Stock temperature: Keep the stock hot. Adding cold stock lengthens cooking time and makes the rice cook unevenly.
# - Stirring frequency: Stir every 1–2 minutes; constant stirring can break the grains.
# - Seafood cooking: Add seafood toward the end and cook briefly. Shrimp and squid become rubbery if overcooked.
# - Check salt carefully: Parmigiano and stock (or fish sauce) contain salt — season gradually.
# - To get creaminess: Add butter and cheese off the heat and stir well to form an emulsion.
# - Leftover risotto: Refrigerate leftovers. Reheat with a little stock/water over low heat and stir to restore creaminess; in a microwave add a splash of liquid and cover.
# - Variations: Instead of mixed seafood, top with smoked salmon or pan-seared fish. Add chili oil or red pepper flakes for a spicy twist.
#
# Eonam’s risotto combines the fresh flavors of seafood with the characteristic creaminess of risotto. The quality of the stock and seafood greatly affects the result, so use the freshest ingredients and hot stock. Enjoy cooking!

# %% [markdown]
# # Cache
#
# - 응답 결과를 저장해서 같은 질문이 들어오면 LLM에 요청하지 않고 저장된 결과를 보여주도록 한다.
#     - 처리속도와 비용을 절감할 수 있다.
#     - 특히 chatbot같이 비슷한 질문을 하는 경우 유용하다.
# - 저장 방식은 `메모리`, `sqlite` 등 다양한 방식을 지원한다.
#
#     ```python
#     set_llm_cache(Cache객체)
#     ```

# %%
from langchain_community.cache import InMemoryCache, SQLiteCache
from langchain_core.globals import set_llm_cache

# set_llm_cache(InMemoryCache()) # 대화내역을 메모리에 저장. 껐다 키면 해제됨. 한번만 선언하면됨.
set_llm_cache(SQLiteCache(database_path="cache.sqlite")) # 대화내역을 SQLite DB에 저장. 디비파일 경로를 지정.

prompt = ChatPromptTemplate(
    [
        ("system", "당신은 유능한 assistant입니다. 공부를 원하는 과목에 대한 학습 커리큘럼을 자세히 짜주세요."),
        ("user", "{query}")
    ]
)
model = ChatOpenAI(model="gpt-5-mini")
chain = prompt | model | StrOutputParser()

# %%
chain.invoke({"query":"AI Agent에 대해 무엇을 공부해야 할지 알려줘."})
# Out:
# '아래는 “AI Agent(지능형 에이전트)”를 체계적으로 공부하기 위한 상세 커리큘럼입니다. 초심자 → 실무자 → 연구자 단계로 구분하고, 각 단계별 핵심 주제, 실습 과제, 추천 자료(강의·책·논문·라이브러리), 목표 및 평가 방법까지 포함했습니다. 본인을 위해 3개월·6개월·1년 로드맵도 제안합니다. 필요하면 학습 기간·관심 분야(로보틱스·대화형 LLM 에이전트·멀티에이전트 등)에 맞춰 커리큘럼을 맞춰드릴게요.\n\n요약(한눈에)\n- 핵심 영역: 확률·선형대수·최적화, 기초 머신러닝, 강화학습(RL), 플래닝·검색, 에이전트 아키텍처(반응형·계획형·하이브리드), LLM 기반 에이전트(도구 사용, 메모리, 체인 오브 소트), 다중 에이전트 시스템(MAS), 평가·안전성·배포\n- 실습 환경: Python, OpenAI Gym/MiniGrid, PettingZoo, Unity ML-Agents, Carla(자율주행), Hugging Face, LangChain, Stable-Baselines3, RLlib\n- 추천 프로젝트: Grid world↑자율 주행 시뮬레이션/대화형 에이전트, 도구 호출 LLM 에이전트, 멀티에이전트 협력/경쟁 실험\n\n1) 시작 전(필수 전제 조건)\n- 수학: 선형대수(행렬·고유값), 확률·통계(조건부확률·MAP·MLE), 미적분(편미분)\n- 프로그래밍: Python (numpy, pandas), 버전관리(Git)\n- 기초 ML: 지도학습(회귀·분류), 신경망 기본(퍼셉트론·역전파), PyTorch 또는 TensorFlow 기본\n\n2) 학습 로드맵(단계별 상세)\n\nA. 기초(2–4주)\n목표: 에이전트의 개념·환경·보상·행동 사이클 이해\n- 개념: 에이전트/환경/상태·행동·보상·정책·가치함수·에피소드\n- 탐색 주제: MDP(마르코프 결정 과정), 벨만 방정식\n- 실습: OpenAI Gym 기본 예제(CartPole, MountainCar)\n추천 자료:\n- 책: Sutton & Barto, “Reinforcement Learning: An Introduction” (챕터 1–3)\n- 강의: David Silver의 RL 강의(강의노트/영상)\n\nB. 기본 강화학습(4–8주)\n목표: 주요 RL 알고리즘(모델프리/모델기반) 이해 및 구현\n- 주제:\n  - 모델프리: Monte-Carlo, TD(λ), SARSA, Q-learning\n  - 근사함수: DQN(딥큐네트워크), 경험재현, 타깃 네트워크\n  - 정책기반: REINFORCE, Actor-Critic, A2C/A3C\n  - 최신: PPO, SAC(Soft Actor-Critic)\n- 실습:\n  - DQN 기본 구현 및 안정화 기법 실험\n  - Stable-Baselines3로 PPO/SAC 적용, 하이퍼파라미터 비교\n- 자료:\n  - Sutton & Barto (더 많은 챕터)\n  - OpenAI Spinning Up (핵심 구현과 설명)\n  - Stable-Baselines3 GitHub\n\nC. 계획·검색·계층적 에이전트(3–6주)\n목표: 고수준 의사결정, 플래닝(모델기반), 계층적 강화학습\n- 주제:\n  - 고전적 AI 플래닝(그래프 탐색, A*)\n  - 모델 기반 RL(world models, planning in latent space)\n  - 계층적 RL(Hierarchical RL, options, feudal RL)\n- 실습:\n  - 간단한 플래너(예: A*상에서 경로계획)\n  - World Models / Dreamer 같은 모델기반 기법 실험\n- 자료:\n  - 논문: “World Models”(Ha & Schmidhuber), “Dreamer”(Hafner et al.)\n\nD. LLM 기반 에이전트(대화형·도구 사용)(4–8주)\n목표: 대형 언어모델(LLM)을 에이전트로 구성하는 방법들(프롬프트 설계, 플래너-실행자 구조, 도구 통합)\n- 주제:\n  - 에이전트 패턴: 프롬프트 기반, Planner-Executor, Reactive vs Deliberative\n  - 도구 통합: 검색, API 호출, 코드 실행, 데이터베이스 조회\n  - 메모리·상태 유지: Retrieval-Augmented Generation(RAG), 장기 메모리 설계\n  - 행동 제어: ReAct(Reason+Action), Chain-of-Thought, Tree of Thoughts\n- 실습:\n  - LangChain으로 간단한 도구 사용 에이전트 구현(검색 + 계산)\n  - ReAct 스타일 디버깅/행동 로그 수집 실험\n  - 추가: Auto-GPT / BabyAGI 같은 오픈소스 에이전트 프레임워크 분석\n- 자료:\n  - 논문/블로그: ReAct, Chain of Thought, Tree of Thoughts, SayCan(로보틱스 + LLM)\n  - 라이브러리: LangChain, LlamaIndex(현 RAG 툴들), Hugging Face Transformers\n\nE. 다중 에이전트 시스템(MAS) & 협력·경쟁(3–6주)\n목표: 멀티에이전트 상호작용, 게임 이론, 협력/경쟁 전략\n- 주제:\n  - 파트너 모델링, 자원 분배, 보상 설계, 자기상대학습(self-play)\n  - 알고리즘: MADDPG, QMIX, population-based training\n- 실습:\n  - PettingZoo/MA-Gym 환경에서 협력/경쟁 실험\n  - 간단한 자원 할당 시뮬레이션\n- 자료:\n  - PettingZoo 문서, multi-agent RL 논문들\n\nF. 평가·안전·윤리·배포(계속 학습)\n목표: 실제 사용 가능한 에이전트 개발을 위한 품질검증, 안전성, 배포 기술\n- 주제:\n  - 성능 지표: 누적 보상, 샘플 효율, 일반화, 안정성\n  - 안전: 보상 설계 오류, 악용 방지, 견고성(Adversarial testing), 검증\n  - 배포: 모델 서빙, 모니터링, 온라인 학습/Continual Learning\n- 실습:\n  - 에이전트 평가 스위트 만들기(로그/메트릭)\n  - 간단한 REST API로 에이전트 서빙 + 모니터링 대시보드\n- 자료:\n  - Alignment/AI Safety 관련 리소스(기본 개념들)\n  - MLOps 문서(모델 버전관리, 서빙)\n\n3) 프로젝트(난이도별) — 실전으로 배우기\n초급(1–2주)\n- Grid world 정책 학습: Q-learning/DQN으로 목표까지 도달\n- 도구: Gym, PyTorch\n\n중급(3–6주)\n- DQN → PPO로 업그레이드: 여러 환경(Atari/Continuous control) 비교\n- LLM 도구 에이전트: 검색+계산으로 질문 답변, LangChain 사용\n\n고급(6–12주)\n- 멀티에이전트 협력 게임(예: 포획·수송 과제)에서 QMIX 또는 population-based training 적용\n- 에뮬레이터(예: Habitat/Unity)에서 시각적 임베딩을 사용한 로보틱스 태스크\n- 복잡한 LLM 에이전트: Planner (Tree of Thoughts) + Executor(도구 + 코드 실행) + 장기 메모리 통합\n\n프로젝트 체크리스트:\n- 목표·성능 메트릭 정의\n- 재현 가능한 실험 환경(Seed 고정, config 파일)\n- 결과 기록(로그·모델 스냅샷)\n- 간단한 보고서(문제 정의, 방법, 결과, 한계)\n\n4) 실습 환경·툴 목록(권장)\n- 환경: OpenAI Gym, MiniGrid, Atari, DMControl, PettingZoo, Unity ML-Agents, CARLA\n- 라이브러리: PyTorch, TensorFlow, Stable-Baselines3, RLlib(Ray), Hugging Face Transformers\n- LLM 에이전트 툴: LangChain, LlamaIndex, OpenAI API, Hugging Face\n- 도구: Weights & Biases(실험 추적), Docker, Kubernetes(대규모 배포 시)\n\n5) 중요한 논문·읽을거리(핵심) ...

# %%
print(chain.invoke({"query":"AI Agent에 대해 무엇을 공부해야 할지 알려줘."}))
# Out:
# 아래는 “AI Agent(지능형 에이전트)”를 체계적으로 공부하기 위한 상세 커리큘럼입니다. 초심자 → 실무자 → 연구자 단계로 구분하고, 각 단계별 핵심 주제, 실습 과제, 추천 자료(강의·책·논문·라이브러리), 목표 및 평가 방법까지 포함했습니다. 본인을 위해 3개월·6개월·1년 로드맵도 제안합니다. 필요하면 학습 기간·관심 분야(로보틱스·대화형 LLM 에이전트·멀티에이전트 등)에 맞춰 커리큘럼을 맞춰드릴게요.
#
# 요약(한눈에)
# - 핵심 영역: 확률·선형대수·최적화, 기초 머신러닝, 강화학습(RL), 플래닝·검색, 에이전트 아키텍처(반응형·계획형·하이브리드), LLM 기반 에이전트(도구 사용, 메모리, 체인 오브 소트), 다중 에이전트 시스템(MAS), 평가·안전성·배포
# - 실습 환경: Python, OpenAI Gym/MiniGrid, PettingZoo, Unity ML-Agents, Carla(자율주행), Hugging Face, LangChain, Stable-Baselines3, RLlib
# - 추천 프로젝트: Grid world↑자율 주행 시뮬레이션/대화형 에이전트, 도구 호출 LLM 에이전트, 멀티에이전트 협력/경쟁 실험
#
# 1) 시작 전(필수 전제 조건)
# - 수학: 선형대수(행렬·고유값), 확률·통계(조건부확률·MAP·MLE), 미적분(편미분)
# - 프로그래밍: Python (numpy, pandas), 버전관리(Git)
# - 기초 ML: 지도학습(회귀·분류), 신경망 기본(퍼셉트론·역전파), PyTorch 또는 TensorFlow 기본
#
# 2) 학습 로드맵(단계별 상세)
#
# A. 기초(2–4주)
# 목표: 에이전트의 개념·환경·보상·행동 사이클 이해
# - 개념: 에이전트/환경/상태·행동·보상·정책·가치함수·에피소드
# - 탐색 주제: MDP(마르코프 결정 과정), 벨만 방정식
# - 실습: OpenAI Gym 기본 예제(CartPole, MountainCar)
# 추천 자료:
# - 책: Sutton & Barto, “Reinforcement Learning: An Introduction” (챕터 1–3)
# - 강의: David Silver의 RL 강의(강의노트/영상)
#
# B. 기본 강화학습(4–8주)
# 목표: 주요 RL 알고리즘(모델프리/모델기반) 이해 및 구현
# - 주제:
#   - 모델프리: Monte-Carlo, TD(λ), SARSA, Q-learning
#   - 근사함수: DQN(딥큐네트워크), 경험재현, 타깃 네트워크
#   - 정책기반: REINFORCE, Actor-Critic, A2C/A3C
#   - 최신: PPO, SAC(Soft Actor-Critic)
# - 실습:
#   - DQN 기본 구현 및 안정화 기법 실험
#   - Stable-Baselines3로 PPO/SAC 적용, 하이퍼파라미터 비교
# - 자료:
#   - Sutton & Barto (더 많은 챕터)
#   - OpenAI Spinning Up (핵심 구현과 설명)
#   - Stable-Baselines3 GitHub
#
# C. 계획·검색·계층적 에이전트(3–6주)
# 목표: 고수준 의사결정, 플래닝(모델기반), 계층적 강화학습
# - 주제:
#   - 고전적 AI 플래닝(그래프 탐색, A*)
#   - 모델 기반 RL(world models, planning in latent space)
#   - 계층적 RL(Hierarchical RL, options, feudal RL)
# - 실습:
#   - 간단한 플래너(예: A*상에서 경로계획)
#   - World Models / Dreamer 같은 모델기반 기법 실험
# - 자료:
#   - 논문: “World Models”(Ha & Schmidhuber), “Dreamer”(Hafner et al.)
#
# D. LLM 기반 에이전트(대화형·도구 사용)(4–8주)
# 목표: 대형 언어모델(LLM)을 에이전트로 구성하는 방법들(프롬프트 설계, 플래너-실행자 구조, 도구 통합)
# - 주제:
#   - 에이전트 패턴: 프롬프트 기반, Planner-Executor, Reactive vs Deliberative
#   - 도구 통합: 검색, API 호출, 코드 실행, 데이터베이스 조회
#   - 메모리·상태 유지: Retrieval-Augmented Generation(RAG), 장기 메모리 설계
#   - 행동 제어: ReAct(Reason+Action), Chain-of-Thought, Tree of Thoughts
# - 실습:
#   - LangChain으로 간단한 도구 사용 에이전트 구현(검색 + 계산)
#   - ReAct 스타일 디버깅/행동 로그 수집 실험
#   - 추가: Auto-GPT / BabyAGI 같은 오픈소스 에이전트 프레임워크 분석
# - 자료:
#   - 논문/블로그: ReAct, Chain of Thought, Tree of Thoughts, SayCan(로보틱스 + LLM)
#   - 라이브러리: LangChain, LlamaIndex(현 RAG 툴들), Hugging Face Transformers
#
# E. 다중 에이전트 시스템(MAS) & 협력·경쟁(3–6주)
# 목표: 멀티에이전트 상호작용, 게임 이론, 협력/경쟁 전략
# - 주제:
#   - 파트너 모델링, 자원 분배, 보상 설계, 자기상대학습(self-play)
#   - 알고리즘: MADDPG, QMIX, population-based training
# - 실습:
#   - PettingZoo/MA-Gym 환경에서 협력/경쟁 실험
#   - 간단한 자원 할당 시뮬레이션
# - 자료:
#   - PettingZoo 문서, multi-agent RL 논문들
#
# F. 평가·안전·윤리·배포(계속 학습)
# 목표: 실제 사용 가능한 에이전트 개발을 위한 품질검증, 안전성, 배포 기술
# - 주제:
#   - 성능 지표: 누적 보상, 샘플 효율, 일반화, 안정성
#   - 안전: 보상 설계 오류, 악용 방지, 견고성(Adversarial testing), 검증
#   - 배포: 모델 서빙, 모니터링, 온라인 학습/Continual Learning
# - 실습:
#   - 에이전트 평가 스위트 만들기(로그/메트릭)
#   - 간단한 REST API로 에이전트 서빙 + 모니터링 대시보드
# - 자료:
#   - Alignment/AI Safety 관련 리소스(기본 개념들)
#   - MLOps 문서(모델 버전관리, 서빙)
#
# 3) 프로젝트(난이도별) — 실전으로 배우기
# 초급(1–2주)
# - Grid world 정책 학습: Q-learning/DQN으로 목표까지 도달
# - 도구: Gym, PyTorch
#
# 중급(3–6주)
# - DQN → PPO로 업그레이드: 여러 환경(Atari/Continuous control) 비교
# - LLM 도구 에이전트: 검색+계산으로 질문 답변, LangChain 사용
#
# 고급(6–12주)
# - 멀티에이전트 협력 게임(예: 포획·수송 과제)에서 QMIX 또는 population-based training 적용
# - 에뮬레이터(예: Habitat/Unity)에서 시각적 임베딩을 사용한 로보틱스 태스크
# - 복잡한 LLM 에이전트: Planner (Tree of Thoughts) + Executor(도구 + 코드 실행) + 장기 메모리 통합
#
# 프로젝트 체크리스트:
# - 목표·성능 메트릭 정의
# - 재현 가능한 실험 환경(Seed 고정, config 파일)
# - 결과 기록(로그·모델 스냅샷)
# - 간단한 보고서(문제 정의, 방법, 결과, 한계)
#
# 4) 실습 환경·툴 목록(권장)
# - 환경: OpenAI Gym, MiniGrid, Atari, DMControl, PettingZoo, Unity ML-Agents, CARLA
# - 라이브러리: PyTorch, TensorFlow, Stable-Baselines3, RLlib(Ray), Hugging Face Transformers
# - LLM 에이전트 툴: LangChain, LlamaIndex, OpenAI API, Hugging Face
# - 도구: Weights & Biases(실험 추적), Docker, Kubernetes(대규모 배포 시)
#
# 5) 중요한 논문·읽을거리(핵심)
# - Sutton & Barto, “Reinforcement Learning: An Introduction” (교과서)
# - Mnih et al., “Human-level control through deep reinforcement learning” (DQN)
# - Schulman et al., “Proximal Policy Optimization” (PPO)
# - Haarnoja et al., “Soft Actor-Critic” (SAC)
# - Ha & Schmidhuber, “World Models”
# - Hafner et al., “Dreamer”
# - Yao et al., “ReAct: Synergizing Reasoning and Acting in Language Models”
# - Yao et al., “Tree of Thoughts”
# - SayCan (Google) — 로보틱스에서 LLM 활용 사례
#
# 6) 추천 강의·코스
# - David Silver (DeepMind) — Reinforcement Learning
# - OpenAI Spinning Up in Deep RL
# - Stanford CS234 (Reinforcement Learning)
# - Hugging Face course (Transformers·RAG)
# - Fast.ai / DeepLearning.ai(실전 딥러닝)
#
# 7) 학습 계획 예시
# A) 3개월 집중 트랙 (주 15–20시간)
# - 1–2주: 수학·파이썬 복습, RL 기초(MDP, 정책/가치)
# - 3–6주: DQN → PPO/SAC 실습 + Gym 환경
# - 7–9주: 모델 기반/계층적 RL(간단한 모델 실험)
# - 10–12주: LLM 기반 에이전트(도구 통합, LangChain) + 최종 프로젝트
#
# B) 6개월 심화 트랙 (주 8–10시간)
# - 1–4주: 기초 및 ML 복습
# - 5–12주: RL 기본/심화 알고리즘(이론 + 실습)
# - 13–20주: 모델기반/계층화/멀티에이전트
# - 21–24주: LLM 에이전트 설계, 배포, 안전성, 최종 종합 프로젝트
#
# C) 1년 연구자 트랙
# - 위의 내용을 더 깊게 파고들며 최신 논문 구현, 새로운 알고리즘 실험, 논문 작성/발표 목표
#
# 8) 평가·점검 항목 (학습 중간·마무리)
# - 알고리즘을 수학적으로 설명할 수 있는가? (벨만 방정식, 정책 경사)
# - 기본 알고리즘을 코드로 구현하고 성능을 재현할 수 있는가?
# - 실험 설계(대조군, 시드, 메트릭)를 하여 결과를 해석할 수 있는가?
# - LLM 에이전트를 설계해 도구 호출, 메모리, 안전 장치를 구현할 수 있는가?
# - 배포 가능한 형태(API/컨테이너)로 서빙해 모니터링할 수 있는가?
#
# 9) 팁과 우선순위
# - 실습을 많이 하세요. RL은 이론보다 실험에서 얻는 통찰이 큽니다.
# - 작은 환경(Gym, MiniGrid)에서 안정적으로 결과 재현하는 능력을 먼저 키우세요.
# - LLM 에이전트는 프롬프트·도구 통합·상태관리(메모리)가 핵심입니다. 간단한 파이프라인으로 시작하세요.
# - 안전성과 보상 설계는 초반부터 신경쓰세요(의도치 않은 행동 방지).
#
# 원하시면:
# - 현재 레벨(수학·프로그래밍·ML 경험)에 맞춘 주간 학습 플랜(요일별·시간대별)을 구체적으로 만들어 드리겠습니다.
# - 관심 분야(로보틱스·챗봇형 에이전트·게임 에이전트·멀티에이전트) 선택 시 그에 맞는 프로젝트·환경·논문 목록으로 맞춤 설계해 드립니다.
#
# 어떤 수준(초보/중급/연구자)이고, 얼마나 많은 시간(주당 몇 시간)을 투입할 수 있는지 알려주시면 구체적인 주간 스케줄과 첫 4주 학습 플랜을 만들어 드리겠습니다.
