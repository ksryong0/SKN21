# %%
from itertools import permutations
from itertools import combinations
# def dfs(curr, arr):
#     if len(arr) == 0: return

def solution(numbers, target):
    answer = 0
    add_or_minus = ['+', '-']
    print(len(numbers))
    print(len(add_or_minus))
    cnt = 0
    for i in combinations(numbers,len(numbers)):
        print(i)
        cnt += 1
    print(f"cnt = {cnt}")
    return answer

solution([1, 1, 1, 1, 1], 3)
# Out:
# 5
# 2
# (1, 1, 1, 1, 1)
# cnt = 1
# 0
